# %% [markdown]
# We canonicalize and tokenize ingredient lists because raw INCI text contains inconsistent naming (synonyms, formatting variants) that would fragment features and weaken TF-IDF. In this notebook we briefly explore the most common ingredient tokens and edge cases, then define a synonym → canonical dictionary and apply it to produce cleaned ingredient tokens per product for downstream feature engineering.

# %%
import pandas as pd
import numpy as np
import re
import json
from pathlib import Path
from typing import List, Dict, Tuple, Optional
from collections import Counter
import matplotlib.pyplot as plt


df = pd.read_csv("cosmetics_processed.csv")

# %%
df["Ingredients"].head(10)
# Out:
# 0    algae (seaweed) extract, mineral oil, petrolat...
# 1    galactomyces ferment filtrate (pitera), butyle...
# 2    water, dicaprylyl carbonate, glycerin, ceteary...
# 3    algae (seaweed) extract, cyclopentasiloxane, p...
# 4    water, snail secretion filtrate, phenyl trimet...
# 5    water, saccharomyces/camellia sinensis leaf/cl...
# 6    water, glycerin, caprylic/ capric triglyceride...
# 7    100% unrefined sclerocraya birrea (marula) ker...
# 8    water, glycerin, cyclohexasiloxane, squalane, ...
# 9    algae (seaweed) extract, mineral oil, petrolat...
# Name: Ingredients, dtype: object

# %%
def split_tokens(s):
    if pd.isna(s) or not str(s).strip():
        return []
    return [t.strip().lower() for t in str(s).split(",") if t.strip()]


all_tokens = []
for s in df["Ingredients"]:
    all_tokens.extend(split_tokens(s))

cnt = Counter(all_tokens)

print("Products:", len(df))
print("Total tokens (with repeats):", len(all_tokens))
print("Unique tokens:", len(cnt))

cnt.most_common(30)
# Out:
# Products: 1472
# Total tokens (with repeats): 45812
# Unique tokens: 6143
# [('water', 995),
#  ('glycerin', 980),
#  ('phenoxyethanol', 806),
#  ('butylene glycol', 788),
#  ('disodium edta', 547),
#  ('sodium hyaluronate', 476),
#  ('caprylyl glycol', 461),
#  ('dimethicone', 442),
#  ('xanthan gum', 416),
#  ('tocopheryl acetate', 415),
#  ('ethylhexylglycerin', 398),
#  ('citric acid', 347),
#  ('tocopherol', 313),
#  ('caprylic/capric triglyceride', 310),
#  ('potassium sorbate', 301),
#  ('carbomer', 297),
#  ('sodium hydroxide', 278),
#  ('fragrance', 270),
#  ('sodium benzoate', 260),
#  ('limonene', 249),
#  ('propanediol', 245),
#  ('silica', 242),
#  ('linalool', 240),
#  ('glyceryl stearate', 239),
#  ('pentylene glycol', 226),
#  ('caffeine', 211),
#  ('polysorbate 20', 207),
#  ('squalane', 206),
#  ('1', 198),
#  ('cetearyl alcohol', 195)]

# %%
# tokens containing parentheses
paren = [t for t in cnt if "(" in t or ")" in t]
print("Tokens with parentheses:", len(paren))
paren[:30]
# Out:
# Tokens with parentheses: 1571
# ['algae (seaweed) extract',
#  'citrus aurantifolia (lime) extract',
#  'sesamum indicum (sesame) seed oil',
#  'eucalyptus globulus (eucalyptus) leaf oil',
#  'sesamum indicum (sesame) seed powder',
#  'medicago sativa (alfalfa) seed powder',
#  'helianthus annuus (sunflower) seedcake',
#  'prunus amygdalus dulcis (sweet almond) seed meal',
#  'galactomyces ferment filtrate (pitera)',
#  'butyrospermum parkii (shea butter)',
#  'citrus aurantifolia (lime) peel extract',
#  'glycine soja (soybean) seed extract',
#  'citrus medica limonum (lemon) peel oil',
#  'citrus aurantium bergamia (bergamot) fruit oil',
#  'citrus aurantium dulcis (orange) peel oil',
#  'citrus aurantifolia (lime) oil',
#  'vitis vinifera (grape) seed oil',
#  'persea gratissima (avocado) oil',
#  'citrus grandis (grapefruit) peel oil',
#  'olea europaea (olive) leaf extract',
#  'glycine soja (soybean) sprout extract',
#  'curcuma longa (turmeric) root extract',
#  'chlorhexidine digluconate. may contain: iron oxides (ci 77492',
#  'ci 77499).',
#  'pistacia lentiscus (mastic) gum',
#  'pseudozyma epicola/camellia sinensis seed oil/glucose/glycine soja meal/malt extract/yeast extract ferment filtrate (pseudozyma epicola/camellia sinensis seed oil/glucose/yeast extract ferment filtrate)',
#  'citrullus lanatus (watermelon) seed oil',
#  '100% unrefined sclerocraya birrea (marula) kernel oil.',
#  'ficus carica (fig) fruit extract',
#  'citrus limon (lemon) peel oil']

# %%
# This finds ingredient tokens that include extra notes in parentheses (e.g., "aqua (water)") and records a clean version with the parentheses removed.
# Output is a list of (original_token, cleaned_token) pairs so we can decide which mappings to add to the synonym → canonical dictionary.
def strip_parentheses(t):
    return re.sub(r"\s*\([^)]*\)", "", t).strip()


paren_pairs = []
for t in paren[:5000]:
    stripped = strip_parentheses(t)
    if stripped and stripped != t:
        paren_pairs.append((t, stripped))

paren_pairs[:30]
# Out:
# [('algae (seaweed) extract', 'algae extract'),
#  ('citrus aurantifolia (lime) extract', 'citrus aurantifolia extract'),
#  ('sesamum indicum (sesame) seed oil', 'sesamum indicum seed oil'),
#  ('eucalyptus globulus (eucalyptus) leaf oil', 'eucalyptus globulus leaf oil'),
#  ('sesamum indicum (sesame) seed powder', 'sesamum indicum seed powder'),
#  ('medicago sativa (alfalfa) seed powder', 'medicago sativa seed powder'),
#  ('helianthus annuus (sunflower) seedcake', 'helianthus annuus seedcake'),
#  ('prunus amygdalus dulcis (sweet almond) seed meal',
#   'prunus amygdalus dulcis seed meal'),
#  ('galactomyces ferment filtrate (pitera)', 'galactomyces ferment filtrate'),
#  ('butyrospermum parkii (shea butter)', 'butyrospermum parkii'),
#  ('citrus aurantifolia (lime) peel extract',
#   'citrus aurantifolia peel extract'),
#  ('glycine soja (soybean) seed extract', 'glycine soja seed extract'),
#  ('citrus medica limonum (lemon) peel oil', 'citrus medica limonum peel oil'),
#  ('citrus aurantium bergamia (bergamot) fruit oil',
#   'citrus aurantium bergamia fruit oil'),
#  ('citrus aurantium dulcis (orange) peel oil',
#   'citrus aurantium dulcis peel oil'),
#  ('citrus aurantifolia (lime) oil', 'citrus aurantifolia oil'),
#  ('vitis vinifera (grape) seed oil', 'vitis vinifera seed oil'),
#  ('persea gratissima (avocado) oil', 'persea gratissima oil'),
#  ('citrus grandis (grapefruit) peel oil', 'citrus grandis peel oil'),
#  ('olea europaea (olive) leaf extract', 'olea europaea leaf extract'),
#  ('glycine soja (soybean) sprout extract', 'glycine soja sprout extract'),
#  ('curcuma longa (turmeric) root extract', 'curcuma longa root extract'),
#  ('pistacia lentiscus (mastic) gum', 'pistacia lentiscus gum'),
#  ('pseudozyma epicola/camellia sinensis seed oil/glucose/glycine soja meal/malt extract/yeast extract ferment filtrate (pseudozyma epicola/camellia sinensis seed oil/glucose/yeast extract ferment filtrate)',
#   'pseudozyma epicola/camellia sinensis seed oil/glucose/glycine soja meal/malt extract/yeast extract ferment filtrate'),
#  ('citrullus lanatus (watermelon) seed oil', 'citrullus lanatus seed oil'),
#  ('100% unrefined sclerocraya birrea (marula) kernel oil.',
#   '100% unrefined sclerocraya birrea kernel oil.'),
#  ('ficus carica (fig) fruit extract', 'ficus carica fruit extract'),
#  ('citrus limon (lemon) peel oil', 'citrus limon peel oil'),
#  ('cucumis sativus (cucumber) fruit extract', 'cucumis sativus fruit extract'),
#  ('stellaria media (chickweed) extract*', 'stellaria media extract*')]

# %%
# tokens with strange punctuation or double spaces
weird = [
    t
    for t in cnt
    if "  " in t or t.endswith(".") or t.endswith("-") or t.startswith("-")
]
print("Weird tokens:", len(weird))
weird[:30]
# Out:
# Weird tokens: 521
# ['alcohol denat.',
#  'fragrance.',
#  'sorbic acid.',
#  'symphytum officinale callus culture extract.',
#  'ci 77499).',
#  'phenoxyethanol. *hadasei-3.',
#  'ethylhexylglycerin.',
#  '100% unrefined sclerocraya birrea (marula) kernel oil.',
#  'caprylyl glycol.',
#  'citral.',
#  'sunflower seed oil.',
#  'linalool. *napiers aqua formula. **napiers original formula. +fragrances of natural origin.',
#  'ci 60725 (violet 2).',
#  'phenoxyethanol.',
#  'geraniol.',
#  'ci 77492. *pitera™.',
#  'iron oxides.',
#  'limonene. *napiers original formula. **napiers moisture formula. ***fragrances of natural origin.',
#  'ci 77891 (titanium dioxide).',
#  'organic argania spinosa (argan) kernel oil*. *organic. **natural.',
#  'titanium dioxide].',
#  'titanium dioxide.',
#  'blue 1 (ci 42090).',
#  'chlorella vulgaris extract.',
#  'moringa pterygosperma seed oil.',
#  'sodium anisate.',
#  'carmine (ci 75470).',
#  'chlorphenesin.',
#  'eugenol*. *plant origin.',
#  'nitrogen. *plant origin.']

# %%
def normalize_basic(t):
    t = t.lower().strip()
    t = re.sub(r"\s+", " ", t)
    t = t.strip(" .-–—_")
    return t


# group tokens by their "basic normalized" form
groups = {}
for t in cnt:
    key = normalize_basic(t)
    groups.setdefault(key, []).append(t)

# show keys that have multiple variants
multi = [(k, v) for k, v in groups.items() if len(v) > 1]
multi[:30]
# Out:
# [('glycerin', ['glycerin', 'glycerin.']),
#  ('sodium gluconate', ['sodium gluconate', 'sodium gluconate.']),
#  ('copper gluconate', ['copper gluconate', 'copper gluconate.']),
#  ('calcium gluconate', ['calcium gluconate', 'calcium gluconate.']),
#  ('zinc gluconate', ['zinc gluconate', 'zinc gluconate.']),
#  ('water', ['water', 'water.']),
#  ('beta-carotene', ['beta-carotene', 'beta-carotene.']),
#  ('citric acid', ['citric acid', 'citric acid.']),
#  ('cyanocobalamin', ['cyanocobalamin', 'cyanocobalamin.']),
#  ('limonene', ['limonene', 'limonene.']),
#  ('geraniol', ['geraniol', 'geraniol.']),
#  ('linalool', ['linalool', 'linalool.']),
#  ('citronellol', ['citronellol', 'citronellol.']),
#  ('benzyl salicylate', ['benzyl salicylate', 'benzyl salicylate.']),
#  ('citral', ['citral', 'citral.']),
#  ('sodium benzoate', ['sodium benzoate', 'sodium benzoate.']),
#  ('alcohol denat', ['alcohol denat.', 'alcohol denat']),
#  ('fragrance', ['fragrance.', 'fragrance']),
#  ('pentylene glycol', ['pentylene glycol', 'pentylene glycol.']),
#  ('methylparaben', ['methylparaben', 'methylparaben.']),
#  ('sorbic acid', ['sorbic acid.', 'sorbic acid']),
#  ('sh-polypeptide-9', ['sh-polypeptide-9', 'sh-polypeptide-9.']),
#  ('heptapeptide-15 palmitate',
#   ['heptapeptide-15 palmitate', 'heptapeptide-15 palmitate.']),
#  ('palmitoyl tetrapeptide-7',
#   ['palmitoyl tetrapeptide-7', 'palmitoyl tetrapeptide-7.']),
#  ('sodium hyaluronate', ['sodium hyaluronate', 'sodium hyaluronate.']),
#  ('linolenic acid', ['linolenic acid', 'linolenic acid. .']),
#  ('lecithin', ['lecithin', 'lecithin.']),
#  ('sodium lactate', ['sodium lactate', 'sodium lactate.']),
#  ('carbomer', ['carbomer', 'carbomer.']),
#  ('polysorbate 20', ['polysorbate 20', 'polysorbate 20.'])]

# %%
mask = df["Ingredients"].str.contains("100%", na=False)
df_percent_rows = df.loc[mask, ["Brand", "Name", "Ingredients"]]

df_percent_rows.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mask = df_step2["Ingredients"].str.contains("100%", na=False)
#       2 df_percent_rows = df_step2.loc[mask, ["Brand", "Name", "Ingredients"]]
#       4 df_percent_rows.head(20)
#
# NameError: name 'df_step2' is not defined

# %% [markdown]
# ## Starting to tweak the ingredient words:

# %% [markdown]
# ### Cleans the raw Ingredients text into a consistent comma-separated string by removing wrappers/marketing noise, normalizing spacing/dashes, and keeping meaningful ingredient info

# %%
# base cleaner (keeps meaningful parentheses like "(ci 77891)",
# but removes wrappers like "+/-", stars, "may contain", marketing sentences, etc.)
def clean_ingredients(ing: str) -> str:
    if not isinstance(ing, str) or not ing.strip():
        return ""

    parts = [p.strip() for p in ing.split(",") if p.strip()]
    cleaned = []

    for raw in parts:
        t = raw.lower().strip()
        t = re.sub(r"\s+", " ", t)
        t = t.replace("–", "-").replace("—", "-")

        # remove leading bullets / stars / simple prefixes
        t = re.sub(r"^[\*\u2022]+\s*", "", t)
        t = re.sub(r"^[\+\-]+\s*", "", t)

        # remove broken "+/-" header/prefix variants

        t = re.sub(
            r"^[\[\(]?\s*[\+\/-]{1,6}\s*(?:may contain|peut contenir)?\s*[\]\):\-]*\s*",
            "",
            t,
        )
        t = re.sub(r"^may contain\s*:?\s*", "", t)
        t = re.sub(r"^peut contenir\s*:?\s*", "", t)

        t = t.strip("[]{}")

        #  "(-)-alpha-bisabolol" -> "alpha-bisabolol"
        t = re.sub(r"^\(\s*[-+]\s*\)\s*-\s*", "", t)

        t = re.sub(r"^\(\s*(?:may contain|\+\/-|\+|\-)\s*\)\s*", "", t)

        m = re.match(r"^\(([^()]{1,80})\)$", t)
        if m:
            t = m.group(1).strip()

        t = re.sub(r"\s*please be aware.*$", "", t)
        t = re.sub(r"\s*ingredient lists may change.*$", "", t)
        t = re.sub(r"\s*please refer.*$", "", t)
        t = re.sub(r"\[\s*\+\/-\s*:.*$", "", t)
        t = re.sub(r"\(\s*\+\/\s*\)\s*:.*$", "", t)
        t = re.sub(r"^\s*may contain\s*:?\s*", "", t)
        t = t.strip(" .;:-")

        if t.count("(") > t.count(")"):
            t = t.split("(", 1)[0].strip()

        t = re.sub(r"[\*\.;:]+$", "", t).strip()
        t = t.strip(" -_")

        # drop obvious marketing / non-ingredient sentences
        if re.search(r"\bpercent\b", t) and any(w in t for w in ["off", "save", "discount", "free shipping"]):
            continue
        if len(t) > 120 and (":" in t or "helps" in t or "step" in t):
            continue
        if "division:" in t or "active ingredients:" in t:
            continue
        if t.startswith("and ") or t.startswith("all products are"):
            continue

        if not t:
            continue

        cleaned.append(t)

    return ", ".join(cleaned)


df_step2 = df.copy()
df_step2["Ingredients"] = df_step2["Ingredients"].apply(clean_ingredients)
df_step2["Ingredients"].head(10)
# Out:
# 0    algae (seaweed) extract, mineral oil, petrolat...
# 1    galactomyces ferment filtrate (pitera), butyle...
# 2    water, dicaprylyl carbonate, glycerin, ceteary...
# 3    algae (seaweed) extract, cyclopentasiloxane, p...
# 4    water, snail secretion filtrate, phenyl trimet...
# 5    water, saccharomyces/camellia sinensis leaf/cl...
# 6    water, glycerin, caprylic/ capric triglyceride...
# 7    100% unrefined sclerocraya birrea (marula) ker...
# 8    water, glycerin, cyclohexasiloxane, squalane, ...
# 9    algae (seaweed) extract, mineral oil, petrolat...
# Name: Ingredients, dtype: object

# %% [markdown]
#  ### Splits the cleaned Ingredients string into a deduplicated list of normalized ingredient tokens (ingredient_tokens) for easier downstream processing.

# %%
def normalize_ingredient_token(token: Optional[str]) -> str:
   
    if not isinstance(token, str) or not token.strip():
        return ""

    t = token.strip().lower()
    t = t.replace("–", "-").replace("—", "-")
    t = re.sub(r"\s+", " ", t)

   
    t = t.strip(" \t\n\r[]{}")

   
    t = t.strip(" .;:-")

    return t

# %%
# Turn the cleaned Ingredients string into a list of tokens
# - Split by commas into ingredient items
# - Normalize again defensively (safe even if already normalized)
# - Deduplicate while preserving order


def ingredient_tokens(ing: str) -> List[str]:
    if not isinstance(ing, str) or not ing.strip():
        return []

    parts = [
        p.strip() for p in ing.split(",") if p.strip()
    ]  
    tokens = [normalize_ingredient_token(p) for p in parts]
    tokens = [t for t in tokens if t and t != "nan"]

    seen, out = set(), []
    for t in tokens:
        if t and t not in seen:
            out.append(t)
            seen.add(t)
    return out


df_step2["ingredient_tokens"] = df_step2["Ingredients"].apply(ingredient_tokens)

# Preview
df_step2[["Brand", "Name", "ingredient_tokens"]].head(5)
# Out:
#             Brand                                         Name  \
# 0          La Mer                              Crème de la Mer
# 1           Sk-Ii                     Facial Treatment Essence
# 2  Drunk Elephant                    Protini Polypeptide Cream
# 3          La Mer                  The Moisturizing Soft Cream
# 4    It Cosmetics  Your Skin But Better CC+ Cream with SPF 50+
#
#                                    ingredient_tokens
# 0  [algae (seaweed) extract, mineral oil, petrola...
# 1  [galactomyces ferment filtrate (pitera), butyl...
# 2  [water, dicaprylyl carbonate, glycerin, cetear...
# 3  [algae (seaweed) extract, cyclopentasiloxane, ...
# 4  [water, snail secretion filtrate, phenyl trime...

# %% [markdown]
# ### Flattens all token lists, counts frequency, and prints the top N most common tokens to help spot typos, variants, and candidates for synonym/canon rules.

# %%
# print all tokens and start scanning for synonimc, then chose canonicals
tokens = [t for toks in df_step2["ingredient_tokens"].dropna() for t in toks if isinstance(toks, list)]
c = Counter(tokens)

TOP_N = 1700

top_tokens = [t for t, _ in c.most_common(TOP_N)]

print("\n".join(top_tokens))
# Out:
# water
# glycerin
# phenoxyethanol
# butylene glycol
# disodium edta
# sodium hyaluronate
# caprylyl glycol
# dimethicone
# tocopheryl acetate
# xanthan gum
# ethylhexylglycerin
# citric acid
# tocopherol
# fragrance
# caprylic/capric triglyceride
# potassium sorbate
# carbomer
# linalool
# sodium hydroxide
# limonene
# sodium benzoate
# silica
# propanediol
# glyceryl stearate
# pentylene glycol
# squalane
# caffeine
# polysorbate 20
# cetearyl alcohol
# lecithin
# 1
# cyclopentasiloxane
# 2-hexanediol
# acrylates/c10-30 alkyl acrylate crosspolymer
# stearic acid
# panthenol
# bht
# peg-100 stearate
# camellia sinensis leaf extract
# hexylene glycol
# chlorphenesin
# mica
# citronellol
# cetyl alcohol
# alcohol
# trehalose
# titanium dioxide (ci 77891)
# geraniol
# sodium citrate
# allantoin
# betaine
# sodium pca
# helianthus annuus (sunflower) seed oil
# sodium chloride
# dipropylene glycol
# alcohol denat
# niacinamide
# algae extract
# lactic acid
# hydrogenated lecithin
# dipotassium glycyrrhizate
# sucrose
# adenosine
# tromethamine
# polysorbate 60
# cucumis sativus (cucumber) fruit extract
# sorbitol
# propylene glycol
# aloe barbadensis leaf juice
# citral
# glycolic acid
# tetrahexyldecyl ascorbate
# ammonium acryloyldimethyltaurate/vp copolymer
# behenyl alcohol
# glycyrrhiza glabra (licorice) root extract
# cholesterol
# polysilicone-11
# maltodextrin
# kaolin
# isohexadecane
# polymethylsilsesquioxane
# potassium hydroxide
# salicylic acid
# ascorbic acid
# arginine
# polysorbate 80
# urea
# benzyl alcohol
# iron oxides
# palmitoyl tetrapeptide-7
# methylparaben
# ascorbyl palmitate
# hydroxyethyl acrylate/sodium acryloyldimethyl taurate copolymer
# titanium dioxide
# c12-15 alkyl benzoate
# acetyl hexapeptide-8
# retinyl palmitate
# hydroxyethylcellulose
# zinc gluconate
# lavandula angustifolia (lavender) oil
# rosmarinus officinalis (rosemary) leaf extract
# cyclohexasiloxane
# linoleic acid
# peg-40 hydrogenated castor oil
# peg-8
# ascorbyl glucoside
# butyrospermum parkii (shea) butter
# ceteareth-20
# acetyl glucosamine
# iron oxides (ci 77491)
# bisabolol
# aluminum hydroxide
# leuconostoc/radish root ferment filtrate
# phospholipids
# peg-60 hydrogenated castor oil
# isododecane
# stearyl alcohol
# palmitic acid
# sorbic acid
# trisodium edta
# helianthus annuus (sunflower) seedcake
# copper gluconate
# dimethicone/vinyl dimethicone crosspolymer
# avena sativa (oat) kernel extract
# pyrus malus (apple) fruit extract
# magnesium aluminum silicate
# citrus aurantium dulcis (orange) peel oil
# cetearyl glucoside
# simmondsia chinensis (jojoba) seed oil
# ethylhexyl palmitate
# benzyl benzoate
# sodium phytate
# yeast extract/faex/extrait de levure
# tetrasodium edta
# sodium polyacrylate
# sigesbeckia orientalis (st. paul's wort) extract
# aloe barbadensis leaf extract
# triethanolamine
# pelargonium graveolens flower oil
# hydrogenated polyisobutene
# hexyl cinnamal
# triethoxycaprylylsilane
# dimethiconol
# hordeum vulgare (barley) extract/extrait d'orge
# peg-10 dimethicone
# isononyl isononanoate
# polyethylene
# dicaprylyl carbonate
# sorbitan isostearate
# citrus aurantium bergamia (bergamot) fruit oil
# palmitoyl oligopeptide
# curcuma longa (turmeric) root extract
# scutellaria baicalensis root extract
# glyceryl stearate se
# steareth-20
# jojoba esters
# cocamidopropyl betaine
# laminaria saccharina extract
# calcium gluconate
# dimethicone crosspolymer
# sodium lactate
# phenyl trimethicone
# butyloctyl salicylate
# glycereth-26
# butylphenyl methylpropional
# chamomilla recutita (matricaria) flower extract
# parfum (fragrance)
# acrylates copolymer
# saccharide isomerate
# inositol
# aminomethyl propanol
# sodium dehydroacetate
# retinol
# laminaria digitata extract
# yellow 5 (ci 19140)
# ci 77492
# phytosphingosine
# methyl gluceth-20
# magnesium ascorbyl phosphate
# benzyl salicylate
# hydrolyzed hyaluronic acid
# ci 77499)
# bis-peg-18 methyl ether dimethyl silane
# disteardimonium hectorite
# lactobacillus ferment
# alpha-isomethyl ionone
# polyacrylamide
# laureth-7
# glyceryl caprylate
# parfum/fragrance
# polymethyl methacrylate
# citrus limon (lemon) peel oil
# zingiber officinale (ginger) root extract
# rosa damascena flower oil
# benzoic acid
# sclerotium gum
# potassium cetyl phosphate
# olea europaea (olive) fruit oil
# sodium metabisulfite
# plankton extract
# c13-14 isoparaffin
# nylon-12
# hydroxyacetophenone
# xylitol
# lauryl peg-9 polydimethylsiloxyethyl dimethicone
# dextrin
# bentonite
# petrolatum
# sorbitan olivate
# chlorella vulgaris extract
# citrus grandis (grapefruit) peel oil
# hydrogenated polydecene
# hyaluronic acid
# sesamum indicum (sesame) seed oil
# vitis vinifera (grape) seed oil
# steareth-21
# salix alba (willow) bark extract
# citrus aurantium dulcis (orange) fruit extract
# polyhydroxystearic acid
# alumina
# ceramide np
# magnesium gluconate
# octyldodecanol
# polyquaternium-51
# niacin
# palmitoyl tripeptide-1
# eucalyptus globulus leaf oil
# propylparaben
# calendula officinalis flower extract
# triethylhexanoin
# limnanthes alba (meadowfoam) seed oil
# corallina officinalis extract
# glyceryl polymethacrylate
# magnesium sulfate
# cetearyl olivate
# persea gratissima (avocado) oil
# tin oxide
# ergothioneine
# propylene glycol dicaprate
# triticum vulgare (wheat) germ extract
# yeast amino acids
# taurine
# butyrospermum parkii (shea butter)
# biotin
# algin
# beta-glucan
# rosmarinus officinalis (rosemary) leaf oil
# methyl methacrylate crosspolymer
# sodium gluconate
# glycine
# cetyl peg/ppg-10/1 dimethicone
# pentaerythrityl tetraethylhexanoate
# saccharomyces lysate extract
# cetyl ethylhexanoate
# synthetic fluorphlogopite
# whey protein/lactis protein/proteine du petit-lait
# sodium ascorbyl phosphate
# prunus amygdalus dulcis (sweet almond) seed meal
# hydrogenated vegetable oil
# citrus limon (lemon) fruit extract
# glycine soja (soybean) oil
# camellia sinensis (green tea) leaf extract
# isostearic acid
# fragrance (parfum)
# cocos nucifera (coconut) oil
# centella asiatica extract
# iron oxides (ci 77492)
# coffea arabica (coffee) seed extract
# algae (seaweed) extract
# eucalyptus globulus (eucalyptus) leaf oil
# medicago sativa (alfalfa) seed powder
# tocopheryl succinate
# hydroxycitronellal
# cellulose gum
# talc
# propylene carbonate
# sodium methyl cocoyl taurate
# sesamum indicum (sesame) seed powder
# linolenic acid
# glucose
# trisodium ethylenediamine disuccinate
# red 4 (ci 14700)
# sorbitan oleate
# peg-40 stearate
# panax ginseng root extract
# melaleuca alternifolia (tea tree) leaf oil
# peg/ppg-18/18 dimethicone
# methylpropanediol
# coco-caprylate/caprate
# polyacrylate crosspolymer-6
# polygonum cuspidatum root extract
# saccharum officinarum (sugar cane) extract
# vitis vinifera (grape) fruit extract
# decyl glucoside
# carthamus tinctorius (safflower) seed oil
# myristic acid
# pullulan
# vitis vinifera (grape) seed extract
# dehydroacetic acid
# caramel
# melia azadirachta leaf extract
# hydrolyzed wheat protein
# sorbitan stearate
# blue 1 (ci 42090)
# neopentyl glycol diheptanoate
# methyl trimethicone
# silica dimethyl silylate
# peg-32
# magnesium aspartate
# glycine soja (soybean) seed extract
# hydrolyzed collagen
# myristyl myristate
# ascorbyl tetraisopalmitate
# melia azadirachta flower extract
# ubiquinone
# hypnea musciformis (algae) extract
# coumarin
# hamamelis virginiana (witch hazel) water
# hdi/trimethylol hexyllactone crosspolymer
# crithmum maritimum extract
# ocimum sanctum leaf extract
# chondrus crispus extract
# rosa damascena flower water
# ethylparaben
# hydrolyzed soy protein
# arnica montana flower extract
# mannitol
# acrylamide/sodium acryloyldimethyltaurate copolymer
# peg-6
# methylisothiazolinone
# pvp
# nordihydroguaiaretic acid
# lauric acid
# proline
# polyvinyl alcohol
# n-hydroxysuccinimide
# sodium hyaluronate crosspolymer
# rubus idaeus (raspberry) leaf extract
# acer saccharum (sugar maple) extract
# ethoxydiglycol
# cyclodextrin
# trisiloxane
# ci 77891 (titanium dioxide)
# rosa canina fruit oil
# charcoal powder
# prunus amygdalus dulcis (sweet almond) oil
# anthemis nobilis flower oil
# phytic acid
# epilobium angustifolium flower/leaf/stem extract
# glucosamine hcl
# cetyl palmitate
# no info
# cellulose
# montmorillonite
# serine
# micrococcus lysate
# dipalmitoyl hydroxyproline
# hydroxypropyl cyclodextrin
# caprylhydroxamic acid
# chrysin
# coco-glucoside
# steareth-2
# methicone
# calcium chloride
# bifida ferment lysate
# ppg-26-buteth-26
# isopropyl palmitate
# oryza sativa (rice) bran extract
# citrus aurantifolia (lime) peel extract
# isopropyl isostearate
# palmitoyl hexapeptide-12
# caprylyl methicone
# vinyl dimethicone/methicone silsesquioxane crosspolymer
# polyisobutene
# sodium metaphosphate
# biosaccharide gum-1
# octyldodecyl neopentanoate
# aminopropyl ascorbyl phosphate
# algae exopolysaccharides
# tourmaline
# glycine soja (soybean) protein
# sodium cocoyl isethionate
# colloidal oatmeal
# dimethicone/peg-10/15 crosspolymer
# lens esculenta (lentil) fruit extract
# saccharomyces cerevisiae extract
# hydroxyethyl urea
# sodium acrylate/sodium acryloyldimethyl taurate copolymer
# sorbitan laurate
# citrus aurantium dulcis (orange) oil
# chlorhexidine digluconate
# dimethyl isosorbide
# mentha piperita (peppermint) oil
# eugenol
# cetyl esters
# yeast extract
# chrysanthemum parthenium (feverfew) extract
# elaeis guineensis (palm) oil
# propyl gallate
# gentiana lutea (gentian) root extract
# sclerocarya birrea seed oil
# salicornia herbacea extract
# hydrolyzed algin
# lauryl glucoside
# hydroxyproline
# cyclomethicone
# butylparaben
# camellia oleifera leaf extract
# hydrolyzed rice extract
# pisum sativum (pea) extract
# polyester-8
# peg-12 dimethicone
# hexyl laurate
# boron nitride
# peg-7 glyceryl cocoate
# saccharomyces ferment filtrate
# pentaerythrityl tetra-di-t-butyl hydroxyhydrocinnamate
# chenopodium quinoa seed extract
# farnesol
# trimethylsiloxysilicate
# behenic acid
# caprylic/capric/myristic/stearic triglyceride
# myristyl alcohol
# potassium phosphate
# chitosan
# oleanolic acid
# visit the dior boutique
# tribehenin
# ammonium polyacryloyldimethyl taurate
# sodium rna
# polyglyceryl-4 isostearate
# olea europaea (olive) leaf extract
# gluconolactone
# ferulic acid
# sea water
# mangifera indica (mango) seed butter
# ci 77891
# yellow 6 (ci 15985)
# polyacrylate-13
# coccinia indica fruit extract
# mentha viridis (spearmint) leaf oil
# iron oxides (ci 77499)
# portulaca oleracea extract
# tocotrienols
# borago officinalis seed oil
# palmitoyl tripeptide-5
# aloe barbadensis leaf juice powder
# hydroxypropyl methylcellulose
# disodium cocoamphodiacetate
# simmondsia chinensis (jojoba) seed extract
# nelumbo nucifera flower extract
# arachidyl alcohol
# cocamidopropyl hydroxysultaine
# sodium acetylated hyaluronate
# red 33 (ci 17200)
# polyglycerin-3
# zinc oxide
# vaccinium angustifolium (blueberry) fruit extract
# vanilla planifolia fruit extract
# zinc sulfate
# dicaprylyl ether
# ceramide ap
# sd alcohol 40-b
# anhydroxylitol
# vaccinium myrtillus fruit extract
# edta
# ethylbisiminomethylguaiacol manganese chloride
# astrocaryum murumuru seed butter
# papain
# menthol
# sodium cocoyl glutamate
# alanine
# nepeta cataria extract
# baptisia tinctoria root extract
# sodium stearoyl glutamate
# dipeptide-2
# hesperidin methyl chalcone
# polyquaternium-7
# magnesium chloride
# acetyl dipeptide-1 cetyl ester
# hydrogenated starch hydrolysate
# camelina sativa seed oil
# prunus armeniaca (apricot) kernel oil
# simethicone
# camellia sinensis (white tea) leaf extract
# molasses extract/saccharum officinarum/extrait de melasse
# castanea sativa (chestnut) seed extract
# 3-o-ethyl ascorbic acid
# glycine soja (soybean) sterols
# oryzanol
# punica granatum extract
# menthoxypropanediol
# benzophenone-4
# paeonia suffruticosa root extract
# mandelic acid
# xylitylglucoside
# amyris balsamifera bark oil
# boswellia serrata extract
# phenoxyethanol * essential oil
# aluminum starch octenylsuccinate
# centaurium erythraea (centaury) extract
# citrus reticulata (tangerine) peel extract
# isopropyl myristate
# superoxide dismutase
# peg/ppg-14/7 dimethyl ether
# zinc pca
# ricinus communis (castor) seed oil
# sodium bicarbonate
# peg-8 dimethicone
# lonicera caprifolium (honeysuckle) flower extract
# sodium c14-16 olefin sulfonate
# salix nigra (willow) bark extract
# citrus medica limonum (lemon) peel oil
# ci 77491
# diglycerin
# stellaria media (chickweed) extract
# ceramide 3
# c14-22 alcohols
# honey extract
# royal jelly extract
# polyglyceryl-10 stearate
# thermus thermophillus ferment
# citrus nobilis (mandarin orange) peel oil
# glyceryl polyacrylate
# solanum melongena (eggplant) fruit extract
# hydrolyzed jojoba esters
# pantethine
# peg-75
# achillea millefolium extract
# trihydroxystearin
# microcrystalline cellulose
# ethylhexyl methoxycinnamate
# mica (ci 77019)
# epigallocatechin gallate
# oryza sativa (rice) extract
# glyceryl acrylate/acrylic acid copolymer
# daucus carota sativa (carrot) root extract
# phytantriol
# sea whip extract
# methylchloroisothiazolinone
# malic acid
# glycol distearate
# sodium laureth sulfate
# polyglyceryl-10 laurate
# paraffin
# beta-carotene
# coconut alkanes
# sea salt/maris sal/sel marin
# butylene glycol dicaprylate/dicaprate
# cinnamomum cassia bark extract
# imperata cylindrica root extract
# arachidyl glucoside
# t-butyl alcohol
# ananas sativus (pineapple) fruit extract
# aesculus hippocastanum (horse chestnut) seed extract
# rubus idaeus (raspberry) fruit extract
# hippophae rhamnoides oil
# potassium chloride
# laminaria ochroleuca extract
# ceramide eop
# olea europaea (olive) fruit extract
# shea butter
# beeswax
# dextrin palmitate
# albizia julibrissin bark extract
# hydrolyzed vegetable protein
# lysine
# chondrus crispus (carrageenan) extract
# hydrolyzed rice bran extract
# ginkgo biloba leaf extract
# salvia officinalis (sage) leaf extract
# sodium sulfite
# diethylhexyl syringylidenemalonate
# menthyl lactate
# coco-betaine
# illite
# lonicera japonica (honeysuckle) flower extract
# ceratonia siliqua gum
# threonine
# citrus aurantifolia (lime) oil
# perfluorodecalin
# hydrolyzed silk
# diphenylsiloxy phenyl trimethicone
# peg-150
# echinacea purpurea root extract
# laureth-23
# citrullus lanatus (watermelon) fruit extract
# galactoarabinan
# copper tripeptide-1
# thioctic acid
# betula alba (birch) bark extract
# palmitoyl pentapeptide-4
# bis-diglyceryl polyacyladipate-2
# manganese sulfate
# aloe barbadensis flower extract
# commiphora mukul resin extract
# amyl cinnamal
# phyllostachis bambusoides juice
# hydrogen dimethicone
# glycyrrhetinic acid
# isopropyl titanium triisostearate
# sodium acrylates copolymer
# cetyl ricinoleate
# c12-16 alcohols
# pogostemon cablin oil
# polyglutamic acid
# cananga odorata flower oil
# silica silylate
# bambusa vulgaris (bamboo) extract
# lavandula hybrida oil
# oleic acid
# citrus medica limonum (lemon) fruit extract
# c12-20 alkyl glucoside
# glycine soja (soybean) extract
# macrocystis pyrifera (kelp) extract
# disodium phosphate
# morus nigra (mulberry) root extract
# cetearyl ethylhexanoate
# ethylhexyl stearate
# tetrasodium glutamate diacetate
# anthemis nobilis flower extract
# gellidiela acerosa (algae) extract
# cladosiphon okamuranus extract
# polybutene
# poria cocos sclerotium extract
# methyldihydrojasmonate
# tartaric acid
# salvia sclarea (clary) oil
# dimethyl mea
# gold
# pseudoalteromonas ferment extract
# cetearyl isononanoate
# macadamia ternifolia seed oil
# argania spinosa kernel oil
# haematococcus pluvialis extract
# phytosteryl macadamiate
# glycosyl trehalose
# ethylhexyl salicylate
# butyl methoxydibenzoylmethane
# polyglyceryl-2 diisostearate
# laureth-4
# artemisia absinthium extract
# rosa canina fruit extract
# cocos nucifera (coconut) fruit extract
# peg-150 distearate
# fucus vesiculosus extract
# phosphatidylcholine
# rhodiola rosea root extract
# sorbitan tristearate
# oenothera biennis (evening primrose) oil
# linum usitatissimum (linseed) seed oil
# ribes nigrum (black currant) seed oil
# sodium levulinate
# saccharomyces ferment lysate filtrate
# isopropyl alcohol
# isodecyl neopentanoate
# palmitoyl tripeptide-38
# enantia chlorantha bark extract
# citrus grandis (grapefruit) peel extract
# alcaligenes polysaccharides
# ectoin
# 2-o-ethyl ascorbic acid
# rosmarinus officinalis (rosemary) extract
# potassium sulfate
# decarboxy carnosine hcl
# garcinia mangostana peel extract
# poloxamer 407
# ethylhexyl methoxycrylene
# ci 77891/titanium dioxide
# carica papaya (papaya) fruit extract
# sodium lauroyl glutamate
# declustered water (+)/aqua/eau de-structuree (+)
# zea mays (corn) starch
# ascophyllum nodosum extract
# asparagopsis armata extract
# peg-30 dipolyhydroxystearate
# porphyridium cruentum extract
# diazolidinyl urea
# prunus amygdalus dulcis (sweet almond) seed extract
# natto gum
# cyanocobalamin
# sh-oligopeptide-1
# sh-oligopeptide-2
# sh-polypeptide-1
# sh-polypeptide-9
# creatine
# glycosaminoglycans
# punica granatum seed oil
# peg-9 polydimethylsiloxyethyl dimethicone
# pentaerythrityl tetraisostearate
# hibiscus sabdariffa flower extract
# vitis vinifera (grape) juice extract
# chondrus crispus (carrageenan)
# galactomyces ferment filtrate
# rosa damascena flower extract
# camellia japonica seed oil
# prunus armeniaca (apricot) fruit extract
# polyglyceryl-3 methylglucose distearate
# bakuchiol
# pearl powder
# glyceryl stearate citrate
# magnolia officinalis bark extract
# diamond powder
# visit the shiseido boutique
# ppg-5-ceteth-20
# lavandula angustifolia (lavender) flower/leaf/stem extract
# lycium barbarum fruit extract
# madecassoside
# palmitoyl grape seed extract
# sodium stearoyl lactylate
# propylene glycol stearate
# tapioca starch
# tocopheryl acetate (vitamin e)
# citrullus vulgaris (watermelon) fruit extract
# hydrolyzed corn starch
# opuntia coccinellifera fruit extract
# chlorella protothecoides oil
# sorbitan sesquioleate
# moringa oleifera seed oil
# medicago sativa (alfalfa) extract
# rosa damascena extract
# vp/eicosene copolymer
# tetrapeptide-21
# citrus limon (lemon) peel extract
# glutamic acid
# capryloyl glycine
# sodium phosphate
# palmaria palmata extract
# punica granatum (pomegranate) fruit juice
# pyridoxine hcl
# hamamelis virginiana (witch hazel) leaf extract
# hydrolyzed rice protein
# sodium stearate
# artemia extract
# hydrogenated castor oil
# peg/ppg-17/6 copolymer
# disodium stearoyl glutamate
# hydroxyphenyl propamidobenzoic acid
# cocos nucifera (coconut) water
# dextran
# aniba rosaeodora (rosewood) wood oil
# cymbopogon martini oil
# green 5 (ci 61570)
# hamamelis virginiana (witch hazel)
# dipentaerythrityl tri-polyhydroxystearate
# styrene/acrylates copolymer
# isobutylparaben
# hamamelis virginiana (witch hazel) extract
# epigallocatechin gallatyl glucoside
# carrageenan
# isostearyl neopentanoate
# perfluorohexane
# artemisia princeps leaf extract
# houttuynia cordata extract
# plantago lanceolata leaf extract
# sucrose stearate
# hydrolyzed sodium hyaluronate
# lactobacillus/pumpkin ferment extract
# lactobacillus/punica granatum fruit ferment extract
# phyllanthus emblica fruit extract
# tetrahydrodiferuloylmethane
# butyrospermum parkii butter
# silybum marianum (lady's thistle) extract
# acacia senegal gum
# camellia oleifera seed oil
# rubus fruticosus (blackberry) leaf extract
# sodium polyacrylate starch
# spiraea ulmaria flower extract
# hydroxyethylpiperazine ethane sulfonic acid
# hippophae rhamnoides extract
# phytosteryl/octyldodecyl lauroyl glutamate
# prunus mume fruit extract
# triethyl citrate
# sd alcohol 40-b (alcohol denat.)
# peg/ppg-17/4 dimethyl ether
# ethyl linoleate
# amino esters-1
# isoamyl laurate
# sodium anisate
# squalene
# phytosterols
# citrus aurantium amara (bitter orange) flower water
# gentiana lutea root extract
# c10-18 triglycerides
# sodium lauroyl lactylate
# theanine
# cocos nucifera (coconut) fruit juice
# evodia rutaecarpa fruit extract
# apricot kernel oil
# bupleurum falcatum root extract
# dioscorea villosa (wild yam) root extract
# ascorbyl tocopheryl maleate
# collagen amino acids
# polyglyceryl-3 polydimethylsiloxyethyl dimethicone
# serenoa serrulata fruit extract
# humulus lupulus (hops) extract
# triolein
# crataegus monogyna flower extract
# tremella fuciformis (mushroom) extract
# ci 19140 (yellow 5)
# mimosa tenuiflora bark extract
# hydroxyisohexyl 3-cyclohexene carboxaldehyde
# moringa pterygosperma seed extract
# daucus carota sativa (carrot) seed oil
# honey
# angelica archangelica root extract
# anthemis nobilis (chamomile) flower extract
# bromelain
# aniba rosaeodora (rosewood) wood extract
# sodium propoxyhydroxypropyl thiosulfate silica
# capryloyl salicylic acid
# morus bombycis (mulberry) root extract
# lactose
# stearalkonium hectorite
# visit the sephora collection boutique
# p-anisic acid
# sodium lauryl sulfate
# perilla ocymoides leaf extract
# camphor
# copper pca
# resveratrol
# escin
# theobroma cacao (cocoa) extract
# magnesium stearate
# galactomyces ferment filtrate (pitera)
# folic acid
# rosa multiflora fruit extract
# vaccinium myrtillus fruit/leaf extract
# ocimum basilicum (basil) flower/leaf extract
# aloe barbadensis leaf water
# oleth-10
# agar
# viola tricolor extract
# salvia sclarea (clary) extract
# citrus unshiu peel extract
# oryza sativa (rice) bran oil
# red 4
# hydroxypropyl bispalmitamide mea
# inulin lauryl carbamate
# ceteth-20
# vaccinium macrocarpon (cranberry) seed oil
# hexylresorcinol
# paeonia suffruticosa (peony) root extract
# coleus barbatus extract
# panax ginseng (ginseng) root extract
# anthemis nobilis (chamomile)
# jasminum officinale (jasmine) oil
# eucalyptus globulus leaf extract
# batyl alcohol
# erythritol
# propylene glycol laurate
# polyglyceryl-3 beeswax
# butyrospermum parkii (shea) butter extract
# ceramide ns
# tricholoma matsutake extract
# flavor
# cholesteryl nonanoate
# gelidium cartilagineum extract
# undaria pinnatifida extract
# alteromonas ferment extract
# tetraacetylphytosphingosine
# astaxanthin
# yellow 5
# gelidiella acerosa extract
# padina pavonica thallus extract
# argania spinosa (argan) kernel oil
# echinacea purpurea extract
# eugenia caryophyllus (clove) leaf oil
# glucosyl hesperidin
# peg-6 caprylic/capric glycerides
# soluble collagen
# octinoxate 7.5%
# vaccinium macrocarpon (cranberry) fruit extract
# acrylates/carbamate copolymer
# litsea cubeba fruit oil
# peucedanum graveolens (dill) extract
# palmitoyl grapevine shoot extract
# actinidia chinensis (kiwi) fruit extract
# helianthus annuus (sunflower) seed wax
# trideceth-6
# dimethicone silylate
# citrus aurantium amara (bitter orange) flower extract
# rose extract
# ci 42090 (blue 1)
# lavandula angustifolia (lavender) extract
# cimicifuga racemosa root extract
# visit the lancôme boutique
# lavender oil
# punica granatum fruit extract
# sodium cocoyl glycinate
# sodium lauroyl sarcosinate
# declustered water (-)/aqua/eau de-structuree (-)
# peg-14m
# polyquaternium-10
# soy isoflavones
# quartz
# helianthus annuus (sunflower) seed extract
# hydroxypinacolone retinoate
# kappaphycus alvarezii extract
# sodium ascorbate
# hydrolyzed lupine protein
# microcrystalline wax
# lanolin alcohol
# adenosine phosphate
# snail secretion filtrate
# pueraria lobata root extract
# morus alba fruit extract
# carnitine hcl
# sophora angustifolia root extract
# passiflora edulis seed oil
# propylene glycol dicaprylate/dicaprate
# ficus carica (fig) fruit extract
# cucumis melo cantalupensis fruit extract
# tetrahydrodemethoxydiferuloylmethane
# tetrahydrobisdemethoxydiferuloylmethane
# sodium nitrate
# copper lysinate/prolinate
# methylglucoside phosphate
# chrysanthemum parthenium extract
# hydrolyzed yeast protein
# stearyl glycyrrhetinate
# cera alba (beeswax)
# ceteareth-12
# lactobacillus/soybean ferment extract
# althaea officinalis root extract
# euphrasia officinalis extract
# silybum marianum fruit extract
# hexyldecanol
# sulfur
# citrus paradisi (grapefruit) peel oil
# stearyl behenate
# glyceryl undecylenate
# sodium acryloyldimethyl taurate copolymer
# oryza sativa (rice) germ oil
# beheneth-20
# enteromorpha compressa extract
# diisopropyl sebacate
# aloe barbadensis (aloe vera) leaf juice
# phenethyl alcohol
# calcium carbonate
# arbutin
# methyl glucose sesquistearate
# selaginella lepidophylla extract
# polyglyceryl-10 pentastearate
# zinc oxide (ci 77947)
# polyglyceryl-6 distearate
# peg-240/hdi copolymer bis-decyltetradeceth-20 ether
# ceramide ng
# camellia sinensis leaf water
# sodium benzotriazolyl butylphenol sulfonate
# sambucus nigra fruit extract
# chamomilla recutita (matricaria) flower water
# santalum album (sandalwood) oil
# osmanthus fragrans flower extract
# tribehenin peg-20 esters
# cholesteryl chloride
# dunaliella salina extract
# rice ferment filtrate (sake)
# polybutylene glycol/ppg-9/1 copolymer
# silanetriol
# red 40 (ci 16035)
# spilanthes acmella flower extract
# water (aqua)
# calcium ascorbate
# sodium dilauramidoglutamide lysine
# sorbitan palmitate
# dipeptide diaminobutyroyl benzylamide diacetate
# avocado oil
# sodium sulfate
# oleyl alcohol
# avobenzone 3.0%
# lycium chinense (wolfberry) fruit extract
# leontopodium alpinum extract
# glyceryl behenate
# dimethicone crosspolymer-3
# citrus aurantium bergamia (bergamot) fruit extract
# rosa roxburghii fruit extract
# myristica fragrans (nutmeg) kernel oil
# anogeissus leiocarpus bark extract
# sodium carboxymethyl beta-glucan
# angelica acutiloba root extract
# paeonia albiflora root extract
# zingiber aromaticus extract
# echium plantagineum seed oil
# tamarindus indica seed extract
# sh-polypeptide-22
# sh-polypeptide-45
# sh-polypeptide-8
# octisalate 5.00%
# di-c12-15 alkyl fumarate
# hexyldecyl stearate
# kaempferol
# pongamia pinnata seed extract
# acetic acid
# citrus aurantium amara (bitter orange) peel extract
# bha
# peg-20 glyceryl triisostearate
# lauryl betaine
# zeolite
# juniperus mexicana oil
# prunus persica (peach) fruit extract
# cucumber fruit extract
# peg-120 methyl glucose dioleate
# disodium cocoyl glutamate
# methyl gluceth-10
# caprylyl/capryl glucoside
# citrus aurantium dulcis (orange) peel extract
# gardenia florida fruit extract
# barium sulfate
# palmitoyl hydroxypropyltrimonium amylopectin/glycerin crosspolymer
# peg-60 almond glycerides
# laureth-12
# aminobutyric acid
# methionine
# alaria esculenta extract
# vanillin
# calcium lactate
# peg-8 glyceryl isostearate
# ethylene/acrylic acid copolymer
# glycerin (organic)
# mineral oil
# histidine
# isoleucine
# phenylalanine
# valine
# aspartic acid
# phenylpropanol
# glucose oxidase
# lactoperoxidase
# calcium stearate
# anthemis nobilis flower water
# magnolia kobus bark extract
# diospyros kaki leaf extract
# pantothenic acid
# saccharomyces/camellia sinensis leaf/cladosiphon okamuranus/rice ferment filtrate
# sunflower seed oil
# alchemilla vulgaris leaf extract
# carthamus tinctorius (safflower) oleosomes
# hydrolyzed quinoa
# opuntia ficus-indica extract
# glycyrrhiza glabra root extract
# sodium polyaspartate
# cynara scolymus (artichoke) leaf extract
# lauroyl lysine
# octocrylene
# plumeria rubra flower extract
# ganoderma lucidum (reishi mushroom) extract
# grape seed extract
# peg-5 rapeseed sterol
# hydroxyethyl acrylate
# inositol (rice extract)
# lawsonia inermis (henna) extract
# musa sapientum (banana) fruit extract
# brassica oleracea capitata (cabbage) leaf extract
# vitis vinifera (grape) fruit water
# vitis vinifera (grape) juice
# illicium verum (anise) fruit/seed oil
# sericin
# peg-20 methyl glucose sesquistearate
# asiaticoside
# potassium magnesium aspartate
# octyldodecyl stearoyl stearate
# polyglyceryl-6 polyricinoleate
# peg-8 beeswax
# narcissus tazetta bulb extract
# salvia officinalis (sage) oil
# honey/mel/miel
# capryloyl glycerin/sebacic acid copolymer
# ceramide eos
# saccharomyces/copper ferment
# canola oil
# thymus serpillum extract
# triticum vulgare (wheat) bran extract
# helichrysum arenarium (everlasting) extract
# corn starch
# poloxamer 338
# aqua/water/eau
# ppg-6-decyltetradeceth-30
# citrus grandis (grapefruit) fruit extract
# bidens pilosa extract
# zingiber officinale (ginger) root oil
# dimethylacrylamide/sodium acryloyldimethyltaurate crosspolymer
# syzygium jambos leaf extract
# lauryl peg/ppg-18/18 methicone
# acetyl octapeptide-3
# triheptanoin
# olea europaea (olive) oil
# lepidium sativum sprout extract
# ppg-15 stearyl ether
# cinnamomum camphora (camphor) bark oil
# iris pallida root extract
# ammonium glycyrrhizate
# di-ppg-2 myreth-10 adipate
# di-c12-18 alkyl dimonium chloride
# glycolipids
# hibiscus abelmoschus extract
# cetyl phosphate
# prunus speciosa leaf extract
# sanguisorba officinalis root extract
# citrus junos seed extract
# acacia decurrens flower wax
# dimethoxytolyl propylresorcinol
# sucrose palmitate
# cucumis melo (melon) fruit extract
# phytosteryl canola glycerides
# cordyceps sinensis extract
# cananga odorata flower extract
# rehmannia chinensis root extract
# glyceryl laurate
# fragrance/parfum
# caulerpa lentillifera extract
# aleurites moluccana (kukui) seed oil
# calcium pantothenate
# gardenia tahitensis flower extract
# stearamidopropyl dimethylamine
# polysilicone-2
# hydrogenated coco-glycerides
# ppg-12/smdi copolymer
# mangifera indica (mango) fruit extract
# punica granatum (pomegranate) extract
# caesalpinia spinosa gum
# collagen
# fragaria vesca (strawberry) fruit extract
# peg-800
# centaurea cyanus flower extract
# dipotassium phosphate
# oleth-20
# aqua (water)
# calendula officinalis (calendula) flower extract
# disodium lauryl sulfosuccinate
# ext. violet 2 (ci 60730)
# chamomilla recutita (matricaria) extract
# cocamidopropyl dimethylamine
# 10-hydroxydecanoic acid
# peg-8 laurate
# potassium cocoyl glycinate
# acorus calamus root extract
# hydrogenated palm glycerides
# coconut acid
# jojoba wax peg-120 esters
# allyl methacrylates crosspolymer
# visit the perricone md boutique
# rosa centifolia flower extract
# ci 42090/blue 1
# saxifraga sarmentosa extract
# chromium oxide greens (ci 77288)
# citrus grandis (grapefruit) seed extract
# salicyloyl phytosphingosine
# ppg-1-peg-9 lauryl glycol ether
# yeast polysaccharides
# litchi chinensis seed extract
# solanum lycopersicum (tomato) fruit extract
# aroma
# tyrosine
# hexapeptide-11
# neopentyl glycol diethylhexanoate
# sucrose tetrastearate triacetate
# medicago sativa (alfalfa) seed extract
# brassica oleracea italica (broccoli) extract
# betula alba (birch) extract
# acetyl tetrapeptide-5
# linum usitatissimum (organic linseed) seed oil
# decyl oleate
# diethylhexyl succinate
# isocetyl stearoyl stearate
# chrysanthemum indicum flower extract
# glycine soja (soybean) sprout extract
# thiamine hcl
# riboflavin
# caprylic/ capric triglyceride
# adansonia digitata seed oil
# prunus armeniaca kernel oil
# hibiscus esculentus fruit extract
# peg/ppg/polybutylene glycol-8/5/3 glycerin
# equisetum arvense leaf extract
# propolis extract
# salvia hispanica seed oil
# sodium lauroyl methyl isethionate
# glutamylamidoethyl imidazole
# wheat amino acids
# angelica keiskei extract
# succinoglycan
# symphytum officinale leaf extract
# achillea millefolium flower extract
# citronnellol
# homosalate
# pogostemon cablin (patchouli) oil
# boswellia carterii (olibanum) oil
# centella asiatica (hydrocotyl) extract
# gellidiella acerosa extract
# trideceth-9
# peg-11 methyl ether dimethicone
# fragrance (natural)
# canadian colloidal clay
# sucrose polystearate
# sericin (silk extract)
# peg-75 stearate
# punica granatum (pomegranate) fruit extract
# ethyl macadamiate
# purified water
# foeniculum vulgare (fennel) seed extract
# ferula galbaniflua (galbanum) resin oil
# polyglyceryl-2 triisostearate
# ammonium acryloyldimethyltaurate/beheneth-25 methacrylate crosspolymer
# vegetable collagen
# polyglyceryl-3 polyricinoleate
# pelargonium graveolens (geranium) flower oil
# acrylates/dimethicone copolymer
# chromium oxide greens
# sodium glycerophosphate
# tocopherol (vitamin e)
# trioctyldodecyl citrate
# hydrogenated poly(c6-14 olefin)
# iris florentina root extract
# trideceth-10
# eclipta prostrata extract
# diheptyl succinate
# caprooyl phytosphingosine
# saccharomyces/magnesium ferment
# saccharomyces/zinc ferment
# ceteareth-25
# ethylhexyl isononanoate
# phenyl methicone
# ci 77491 (iron oxides)
# macrocystis pyrifera extract
# codium tomentosum extract
# laminaria japonica extract
# peg-5 glyceryl stearate
# essential oil
# ci 19140
# acetyl tetrapeptide-9
# coco-caprylate
# gossypium herbaceum (cotton) seed oil
# vaccinium myrtillus (bilberry) fruit extract
# panthenol (vitamin b5)
# natural fragrance
# diisostearyl malate
# octinoxate 7.50%
# peg-10 rapeseed sterol
# jojoba alcohol
# stearyl dimethicone
# visit the estée lauder boutique
# ci 77492 (iron oxides)
# cyclotetrasiloxane
# triethoxysilylethyl polydimethylsiloxyethyl hexyl dimethicone
# argania spinosa kernel extract
# sesamum indicum (sesame) seed extract
# acrylates crosspolymer
# polyglyceryl-2 dipolyhydroxystearate
# eugenia caryophyllus (clove) bud oil
# viola odorata flower/leaf extract
# cassia alata leaf extract
# cocoglycerides
# lauryl lactate
# piperidinepropionic acid
# isodonis japonicus leaf/stalk extract
# lamium album flower extract
# octoxynol-9
# tocopheryl linoleate/oleate
# pvp/hexadecene copolymer
# jasminum officinale (jasmine) flower extract
# melissa officinalis leaf extract
# plukenetia volubilis seed oil
# dehydroxanthan gum
# visit the philosophy boutique
# ophiopogon japonicus root extract
# poly c10-30 alkyl acrylate
# hydrolyzed phyllostachis bambusoides
# hydrolyzed camellia sinensis leaf
# camellia sinensis flower extract
# ozokerite
# sweet almond oil
# euphorbia cerifera (candelilla) wax
# copernicia cerifera (carnauba) wax
# rosmarinus officinalis (rosemary) leaf extract (rosmarinus officinalis leaf extract)
# sodium starch octenylsuccinate
# visit the clarins boutique
# lens esculenta (lentil) seed extract
# geranium maculatum oil
# lactobacillus/pumpkin fruit ferment filtrate
# ingredients from organic farming. **clinical grade essential oils blend
# avobenzone 3.00%
# sphingolipids
# laurdimonium hydroxypropyl hydrolyzed soy protein
# ethylhexyl hydroxystearate
# alpha-glucan oligosaccharide
# coconut alcohol
# rosa centifolia flower oil
# ormenis multicaulis oil
# peg-3 distearate
# acrylates/steareth-20 methacrylate copolymer
# fructose
# aluminum stearate
# water/aqua/eau
# magnesium oxide
# yogurt powder
# euterpe oleracea fruit extract
# glycereth-18 ethylhexanoate
# glycereth-18
# oligopeptide-10
# disodium carboxyethyl siliconate
# lithium magnesium sodium silicate
# sapindus mukurossi fruit extract
# macadamia integrifolia seed oil
# passiflora edulis fruit extract
# carthamus tinctorius (safflower) flower extract
# diatomaceous earth
# sodium cocoamphoacetate
# rice amino acids
# sodium lauryl sulfoacetate
# hippophae rhamnoides fruit extract
# microcitrus australasica fruit extract
# peg-150 pentaerythrityl tetrastearate
# rosa centifolia flower water
# acetyl tyrosine
# glutathione
# boswellia carterii oil
# biosaccharide gum - 1
# polysorbate 40
# polyglyceryl-10 oleate
# coptis japonica extract
# leuconostoc ferment filtrate
# borago officinalis (borage) leaf extract
# arnica montana (arnica) extract
# polyglyceryl-4 caprate
# sodium carbomer
# denatonium benzoate
# vanillyl butyl ether
# sodium salicylate
# pinus pinaster bark extract
# parfum
# tetrapotassium pyrophosphate
# distarch phosphate
# chondrus crispus powder
# hydrolyzed wheat protein/pvp crosspolymer
# cucumis sativus (organic cucumber) fruit extract
# oenothera biennis (organic evening primrose) oil
# glyceryl isostearate
# aluminum distearate
# isomalt
# distearyldimonium chloride
# lactobacillus/honeysuckle flower/licorice root/morus alba root/pueraria lobata root/schizandra chinensis fruit/scutellaria baicalensis root/sophora japonica flower extract ferment filtrate
# pentafluoropropane
# persea gratissima oil
# chamomilla recutita (matricaria) flower oil
# saccharum officinarum (sugarcane) extract
# helianthus annuus (sunflower) sprout extract
# raspberry seed oil/tocopheryl succinate aminopropanediol esters
# saccharomyces/xylinum/black tea ferment
# isostearyl isostearate
# methylsilanol tri-peg-8 glyceryl cocoate
# disodium adenosine triphosphate
# sodium hexametaphosphate
# poncirus trifoliata fruit extract
# trifolium pratense (clover) flower extract
# menyanthes trifoliata leaf extract
# nicotiana sylvestris leaf cell culture
# fuscoporia obliqua sclerotium extract
# cordyceps sinensis (mushroom) extract
# ocimum sanctum (holy basil) leaf extract
# hydrolyzed prunus domestica
# ethyl hexanediol
# moroccan lava clay
# blue 1
# #name?
# squalane (olive origin)
# chamomilla recutita (matricaria)
# santalum album (sandalwood) extract
# citrullus lanatus (watermelon) fruit
# ipomoea batatas (sweet potato) root extract
# adipic acid/neopentyl glycol crosspolymer
# simmondsia chinensis (jojoba) butter
# phenoxyethanol. *essential oil
# protease
# aroma/flavor
# acrylates/ethylhexyl acrylate/dimethicone methacrylate copolymer
# asiatic acid
# centella asiatica meristem cell culture
# ci 77492/iron oxides
# ci 77491/iron oxides
# ci 77499/iron oxides
# oenothera biennis (evening primrose) seed extract
# ziziphus jujuba fruit extract
# amaranthus caudatus seed extract
# artemisia vulgaris extract
# camellia sinensis leaf powder
# sodium polyacryloyldimethyl taurate
# avena sativa (oat) bran extract
# camellia sinensis (green tea) leaf powder
# buteth-3
# tris(tetramethylhydroxypiperidinol) citrate
# saccharomyces/iron ferment
# saccharomyces/silicon ferment
# polylactic acid
# pelargonium graveolens oil
# cholesteryl oleyl carbonate
# cholesteryl isostearate
# aspergillus/rice ferment extract
# sapindus mukurossi peel extract
# pca dimethicone
# cyamopsis tetragonoloba (guar) gum
# ocimum basilicum (basil) oil
# faex/yeast extract/extrait de levure
# bismuth oxychloride (ci 77163)
# l-tyrosine
# dimethyl mea (dmae)
# ci 14700
# saccharomyces/xylinum/ black tea ferment
# ci 77492)
# sucrose laurate
# lysolecithin
# amber powder
# ascorbic acid (vitamin c)
# spinacia oleracea (spinach) leaf extract
# amorphophallus konjac root powder
# tin oxide (ci 77861)
# hydroxypropyl tetrahydropyrantriol
# rosa rubiginosa seed oil
# rosmarinus officinalis (rosemary)
# leaf extract
# paeonia lactiflora root extract
# retinyl propionate
# hydrolyzed yeast extract
# cetyl hydroxyethylcellulose
# polyglucuronic acid
# soy amino acids
# lactococcus ferment lysate
# octisalate 4.5%
# magnolia acuminata flower extract
# eugenia caryophyllus (clove) flower extract
# arctostaphylos uva ursi leaf extract
# melia azadirachta seed oil
# paeonia albiflora (peony) root extract
# hydrolyzed soy flour
# peg-20 stearate
# tripleurospermum maritimum extract
# sanicula europaea extract
# glycyl glycine
# peg-60 glyceryl isostearate
# tricaprylin
# ethylcellulose
# myrtus communis oil
# glyceryl linoleate
# limonium vulgare flower/leaf/stem extract
# propylene glycol dicaprylate
# isocetyl stearate
# linalool. *plant origin
# octyldodecyl myristate
# santalum album (sandalwood) wood extract
# microcrystalline wax(cera microcristallina/cire microcristalline)
# alchemilla vulgaris extract
# potato starch modified
# malachite
# nannochloropsis oculata extract
# citrus aurantium amara (bitter orange) flower oil
# polysorbate-20
# ruby powder
# behentrimonium chloride
# disodium acetyl glucosamine phosphate
# disodium edta-copper
# hydrated silica
# ci 42090
# aqua
# sea salt
# rosa moschata seed oil
# isostearyl palmitate
# sucrose distearate
# hydrogenated phosphatidylcholine
# hydroxypropyl starch phosphate
# rosa gallica flower extract
# hydrolyzed elastin
# ascorbyl methylsilanol pectinate
# lavandula angustifolia (lavender)
# arabidopsis thaliana extract
# coffea robusta seed extract
# parachlorella beijerinckii exopolysaccharides
# prunus yedoensis leaf extract
# phoenix dactylifera (date) seed
# amylopectin
# sodium lauroamphoacetate
# sodium trideceth sulfate
# bulnesia sarmientoi wood oil
# piper nigrum (pepper) fruit oil
# oryza sativa (rice) powder
# benzalkonium chloride
# glyceryl oleate
# cinnamal
# sodium coco pg-dimonium chloride phosphate
# peg-4 dilaurate
# lauramidopropyl betaine
# aspalathus linearis leaf extract
# juglans regia (walnut) shell powder
# menthone glycerin acetal
# sodium cocoyl sarcosinate
# tea-cocoyl glutamate
# peg-200 hydrogenated glyceryl palmate
# calendula officinalis extract
# disodium laureth sulfosuccinate
# silver citrate
# hydrolyzed corn starch octenylsuccinate
# beta-sitosterol
# ceteth-24
# choleth-24
# maltooligosyl glucoside
# polyquaternium-4
# polyglyceryl-10 myristate
# sodium lauroyl oat amino acids
# ci 14700 (red 4)
# schizandra chinensis fruit extract
# orange 4 (ci 15510)
# potassium laurate
# potassium azeloyl diglycinate
# jasminum officinale (jasmine) flower/leaf extract
# tridecyl stearate
# tridecyl trimellitate
# dipentaerythrityl hexacaprylate/hexacaprate
# sodium palmitoyl proline
# nymphaea alba flower extract
# hydrogenated palm kernel glycerides
# lemon fruit extract
# octyldodeceth-16
# paullinia cupana seed extract
# cupressus sempervirens leaf/nut/stem oil
# centaurea cyanus flower water
# palmitoyl dipeptide-10
# chrysanthellum indicum extract
# inulin
# quaternium-90 bentonite
# methyl perfluorobutyl ether
# visit the clinique boutique
# laureth-3
# polyglyceryl-3 diisostearate
# passiflora incarnata fruit extract
# tripeptide-32
# oleth-3 phosphate
# raphanus sativus (radish) root extract
# terminalia ferdinandiana fruit extract
# coenzyme a
# c9-12 alkane
# pvm/ma decadiene crosspolymer
# 4-t-butylcyclohexanol
# egf (barley sh-oligopeptide-1)
# dimethicone/bis-isobutyl ppg-20 crosspolymer
# bis-peg/ppg-16/16 peg/ppg-16/16 dimethicone
# shea butter ethyl esters
# trideceth-6 phosphate
# coriandrum sativum (coriander) seed extract
# cupressus sempervirens seed extract
# zea mays (corn) oil
# darutoside
# triacetin
# sodium polyglutamate
# zingiber zerumbet extract
# perfluoroperhydrophenanthrene
# raspberry ketone
# methyl methacrylate/ glycol dimethacrylate crosspolymer
# ethylhexyl cocoate
# mentha piperita (peppermint) leaf extract
# dihydroxyacetone
# leucine
# chromium hydroxide green (ci 77289)
# ethyl perfluorobutyl ether
# ethyl perfluoroisobutyl ether
# pantolactone
# conchiolin powder
# magnolia officinalis flower extract
# epilobium fleischeri extract
# coceth-7
# bioflavonoids
# coptis japonica root extract
# brassica oleracea italica (broccoli) sprout extract
# albumen extract
# myrciaria dubia fruit extract
# polygonum fagopyrum seed extract
# sodium dextran sulfate
# biosaccharide gum-2
# theobroma grandiflorum seed butter
# benzylidene dimethoxydimethylindanone
# alcohol (organic)
# citrus aurantifolia (lime) extract
# sh-polypeptide-11
# acetyl glutamine
# pca
# glyceryl distearate
# steareth-10
# acetyl carnitine hcl
# orbignya oleifera seed oil
# pinus sylvestris leaf oil
# pistacia lentiscus (mastic) gum
# dimethicone/phenyl vinyl dimethicone crosspolymer
# phenoxyethanol. *hadasei-3
# prunus amygdalus dulcis oil
# lepidium meyenii root extract
# sodium acrylate/acryloyldimethyltaurate/dimethylacrylamide crosspolymer
# fragrance+
# sodium methyl oleoyl taurate
# buddleja davidii meristem cell culture
# leontopodium alpinum meristem cell culture
# nylon-6/12
# cucumis sativus(cucumber) fruit extract
# sodium peg-7 olive oil carboxylate
# acanthopanax senticosus (eleuthero) root extract
# sorbitan sesquiisostearate
# peg-20 sorbitan cocoate
# glyceryl behenate/eicosadioate
# turmeric root extract
# willow bark extract
# punica granatum fruit juice
# tamarindus indica seed polysaccharide
# potassium alginate
# ammonium acryloyldimethyltaurate
# vp copolymer
# vinyl dimethicone crosspolymer
# chondrus crispus (red algae) extract
# sapindus mukurossi peel extract (sapindus mukurossi)
# uncaria gambir extract (uncaria gambir)
# caprylic/capric triglycerides
# helianthus annuus seed oil
# caulerpa lentillifera (seaweed) extract
# cucurbita pepo (pumpkin) fruit extract
# rosa damascena (rose) flower water
# carmine (ci 75470)
# lauryl dimethicone
# cucumis sativus (cucumber) extract
# borago officinalis (borage) oil
# rose flower oil
# mentha rotundifolia leaf extract
# origanum majorana leaf extract
# copaifera officinalis (balsam copaiba) resin
# thymus serpyllum extract
# camellia japonica flower extract
# ppg-2 myristyl ether propionate
# centella asiatica leaf water
# diethylhexyl carbonate
# polyglyceryl-4 diisostearate/polyhydroxystearate/sebacate
# madecassic acid
# hexyldecyl laurate
# sodium carboxymethyl betaglucan
# polyester-1
# hordeum vulgare (barley) extract
# citrus reticulata (tangerine) peel oil
# rosa centifolia flower wax
# rosa damascena flower wax
# cymbopogon flexuosus (lemongrass) oil
# isoceteth-20
# malt extract
# ulmus davidiana root extract
# raffinose
# polypropylsilsesquioxane
# gossypium herbaceum (cotton) extract
# viscum album (mistletoe) leaf extract
# caprooyl sphingosine
# glycosphingolipids
# meadowfoam estolide
# caprylic/caprictriglyceride
# sodium carbonate
# dipteryx odorata seed extract
# chlorella minutissima extract
# spirulina platensis extract
# codium fragile extract
# sargassum muticum extract
# jania rubens extract
# macrocystis pyrifera (kelp) protein
# uncaria gambir extract
# ahnfeltia concinna extract
# pyridoxine dipalmitate
# ceratonia siliqua (carob) fruit extract
# visit the jack black boutique
# lavandula hybrida (lavandin) oil
# opuntia coccinellifera flower extract
# alanyl glutamine
# cera alba
# hydrolyzed linseed extract
# carica papaya fruit extract
# citrusgrandis (grapefruit) peel oil
# hydroxyethyl acrylate/sodium acryloyl dimethyl taurate copolymer
# triticum vulgare (wheat) germ oil
# beeswax/cera alba/cire d'abeille
# aloe barbadensis (aloe vera) leaf extract
# chlorophyll
# titanium dioxide (ci77891)
# sodium tetrahydrojasmonate
# microcrystalline wax (cera microcristallina)
# potassium ascorbyl tocopheryl phosphate
# prunus domestica seed oil
# calophyllum inophyllum seed oil
# grapefruit peel oil
# octisalate 4.00%
# oxybenzone 2.50%
# hydroxyethyl acrylate/sodium
# acryloyldimethyl taurate copolymer
# fruit extract
# aesculus hippocastanum (horse chestnut) leaf extract
# rosa canina (rosehip) fruit oil
# olive fruit oil
# potassium jojobate
# gardenia taitensis flower extract
# avena sativa (oat) kernel flour
# swertia chirata leaf extract
# ahnfeltiopsis concinna extract

# %% [markdown]
# ###  Loads synonyms.json once (cached), replaces token variants with their standardized synonym forms, drops tokens mapped to "", and deduplicates again.

# %%
# Apply synonyms from synonyms.json onto token lists
def apply_synonyms_to_tokens(
    tokens: list[str], synonyms_path: str = "synonyms.json"
) -> list[str]:
    # Load + cache synonyms once
    if not hasattr(apply_synonyms_to_tokens, "_syn_cache"):
        p = Path(synonyms_path)
        raw = json.loads(p.read_text(encoding="utf-8")) if p.exists() else {}
        apply_synonyms_to_tokens._syn_cache = {
            normalize_ingredient_token(k): (normalize_ingredient_token(v) if v else "")
            for k, v in raw.items()
        }

    syn = apply_synonyms_to_tokens._syn_cache

    if not isinstance(tokens, list):
        return []

    mapped = []
    for t in tokens:
        t_norm = normalize_ingredient_token(t)
        t_final = syn.get(t_norm, t_norm)  
        if t_final:  # drop "" mappings
            mapped.append(t_final)


    seen, out = set(), []
    for t in mapped:
        if t not in seen:
            out.append(t)
            seen.add(t)
    return out


df_step2["ingredient_tokens"] = df_step2["ingredient_tokens"].apply(
    apply_synonyms_to_tokens
)

# Preview
df_step2[["Brand", "Name", "ingredient_tokens"]].head(5)
# Out:
#             Brand                                         Name  \
# 0          La Mer                              Crème de la Mer
# 1           Sk-Ii                     Facial Treatment Essence
# 2  Drunk Elephant                    Protini Polypeptide Cream
# 3          La Mer                  The Moisturizing Soft Cream
# 4    It Cosmetics  Your Skin But Better CC+ Cream with SPF 50+
#
#                                    ingredient_tokens
# 0  [algae (seaweed) extract, mineral oil, petrola...
# 1  [galactomyces ferment filtrate (pitera), butyl...
# 2  [water, dicaprylyl carbonate, glycerin, cetear...
# 3  [algae (seaweed) extract, cyclopentasiloxane, ...
# 4  [water, snail secretion filtrate, phenyl trime...

# %% [markdown]
# ### Prints the unique token vocabulary after synonym mapping

# %%
all_tokens = (
    pd.Series([t for row in df_step2["ingredient_tokens"] for t in row])
    .dropna()
    .astype(str)
)
unique_tokens = sorted(all_tokens.unique())

print("Unique token count:", len(unique_tokens))
print("\nFirst 300 tokens:\n")
for t in unique_tokens[:1500]:
    print(t)
# Out:
# Unique token count: 5343
#
# First 300 tokens:
#
# (bergamot) fruit oil
# (bilberry) extract
# (evening primrose) oil
# (jojoba) seed oil
# (mel) honey
# (rosemary) leaf extract (rosmarinus officinalis leaf extract)
# *naturally derived fragrance
# /peut contenir/+/-:titanium dioxide (ci 77891)
# 000 percent better than pure ascorbic acid
# 1.2-hexanediol
# 10-decanediol
# 10-hydroxydecanoic acid
# 100 percent pure argan oil: nourishes and protects skin with essential fatty acids
# 100 percent sugarcane-derived squalane
# 100% natural abaca leaf fiber
# 100% natural fragrance
# 100% unrefined sclerocraya birrea (marula) kernel oil
# 15 dimethicone
# 2 hexanediol
# 2-dimethylhydrocinnamal
# 2-hexandiol
# 2-hexanediol
# 2-o-ethyl ascorbic acid
# 3-0-ethyl ascorbic acid
# 3-aminopropane sulfonic acid
# 3-butylene glycol
# 3-methyl-4
# 3-o-ethyl ascorbic acid
# 4 isostearate
# 4-t-butylcyclohexanol
# 6
# 6 copolymer
# 6-naphthalate
# 6-trimethyl-2-cyclohexene-1-yl)-3-butene-2-one
# 7-dehydrocholesterol
# 77491
# 77492 (iron oxides)
# 77499)
# a 70 propellant
# a70 propellant
# abaca leaf
# abies sibirica oil
# abronia villosa leaf extract
# acacia concinna fruit extract
# acacia dealbata flower/stem extract
# acacia decurrens flower cera (wax)
# acacia decurrens flower wax
# acacia decurrens/jojoba/sunflower seed wax
# acacia decurrens/jojoba/sunflower seed wax polyglyceryl-3 esters
# acacia decurrens/jojoba/sunflower seed wax/polyglyceryl-3 esters
# acacia farnesiana (organic acacia) extract
# acacia farnesiana flower wax
# acacia senegal gum
# acacia victoriae fruit extract
# acanthopanax senticosus (eleuthero) root extract
# acanthopanax senticosus root extract/ acanthopanax senticosus (eleuthero) root extract
# acer saccarum (sugar maple) extract
# acer saccharum (sugar maple) extract
# acer saccharum(sugar maple) extract
# acerola fruit extract
# acetamidoethoxyethanol
# acetic acid
# acetyl carnitine hcl
# acetyl citrull amido arginine
# acetyl dipeptide-1 cetyl ester
# acetyl glucosamine
# acetyl glutamine
# acetyl hexapeptide-3
# acetyl hexapeptide-30
# acetyl hexapeptide-8
# acetyl hydroxyproline
# acetyl octapeptide-3
# acetyl tetrapeptide-15. *plant origin
# acetyl tetrapeptide-17
# acetyl tetrapeptide-2
# acetyl tetrapeptide-5
# acetyl tetrapeptide-9
# acetyl tyrosine
# acetylarginyltryptophyl diphenylglycine
# acetylated glycol stearate
# achillea millefolium extract
# achillea millefolium flower extract
# acmella oleracea extract
# acorus calamus root extract
# acrylamide/sodium acryloyldimethyltaurate copolymer
# acrylates
# acrylates /c10-30 alkyl acrylate crosspolymer
# acrylates c10/30 alkyl acrylate crosspolymer
# acrylates copolymer
# acrylates crosspolymer
# acrylates/ dimethicone copolymer
# acrylates/ammonium methacrylate copolymer
# acrylates/beheneth-25 methacrylate copolymer
# acrylates/c10-30 alkyl acrylate copolymer
# acrylates/c10-30 alkyl acrylate cross-polymer
# acrylates/c10-30 alkyl acrylate crosspolymer
# acrylates/c10-30 alykyl acrylate crosspolymer
# acrylates/c10-30 feel the instant firming effect of our indulgent velvety cream mask. formulated with hibiscus
# acrylates/c10-c30 alkyl acrylate crosspolymer
# acrylates/carbamate copolymer
# acrylates/dimethicone co -polymer
# acrylates/dimethicone copolymer
# acrylates/ethylhexyl acrylate/dimethicone methacrylate copolymer
# acrylates/octylacrylamide copolymer
# acrylates/palmeth-25 acrylate copolymer
# acrylates/steareth-20 methacrylate copolymer
# acrylates/stearyl acrylate/dimethicone methacrylate copolymer
# acrylates/tridecyl acrylate/triethoxysilylpropyl methacrylate/dimethicone methacrylate copolymer
# acrylates/vinyl isodecanoate crosspolymer
# acrylatescopolymer
# acrylonitrile/methyl methacrylate/vinylidene chloride copolymer
# acryloyldimethyl taurate copolymer
# acryloyldimethyltaurate/vp copolymer
# actinidia chinensis (kiwi) fruit extract
# actinidia chinensis (kiwi) fruit water
# actinidia polygama fruit extract
# activated bamboo charcoal
# adansonia digitata leaf extract
# adansonia digitata seed oil
# aden-osine
# adenium obesum leaf cell extract
# adenosine
# adenosine phosphate
# adipic acid/diethylene glycol/glycerin
# adipic acid/neopentyl glycol crosspolymer
# aesculus hippocastanum (horse chestnut) bark extract
# aesculus hippocastanum (horse chestnut) extract
# aesculus hippocastanum (horse chestnut) leaf extract
# aesculus hippocastanum (horse chestnut) seed extract
# africana fruit extract
# agar
# agaricus bisporus (mushroom) extract
# agaricus bisporus extract
# agaricus blazei extract
# agarum cribosum extract
# agave americana leaf extract (organic)
# agave tequilana leaf (blue agave) extract
# agave tequilana leaf extract
# ahas
# ahnfeltia concinna extract
# ahnfeltiopsis concinna extract
# ala
# alanine
# alanyl glutamine
# alaria escilenta extract
# alaria esculenta extract
# albiza julibrissin bark extract
# albizia julibrissin bark extract
# albumen extract
# alcaligenes polysaccha-rides
# alcaligenes polysaccharides
# alchemilla vulgaris extract
# alchemilla vulgaris leaf extract
# alchemilla vulgaris leaf extract+
# alcohol
# alcohol (from plant extracts)
# alcohol (organic)
# alcohol .citric acid
# alcohol denat
# alcohol denat (found in botanical extracts)
# alcohol denat. (sd alcohol 40-b)
# aleurites moluccana (kukui nut) seed oil
# aleurites moluccana (kukui) nut oil
# aleurites moluccana (kukui) seed oil
# aleuritic acid
# algae (organic) extract
# algae (seaweed) extract
# algae exopolysaccharides
# algae exopolysacharides
# algae extract
# algae extract (organic)
# algae oligosaccharides
# algin
# algin. *plant origin
# aliphatic alcohols/hydrocarbons
# alkanna tinctoria root extract
# alkanolamines
# allantoin
# allantoin (soothing - comfrey herb)
# allium cepa (onion) bulb extract
# allyl methacrylates crosspolymer
# almond oil
# almond/borage/linseed/olive acids/glycerides
# alnus firmifolia fruit extract
# aloe barba-densis leaf juice powder
# aloe barbadensis
# aloe barbadensis (aloe vera) leaf extract
# aloe barbadensis (aloe vera) leaf juice
# aloe barbadensis (organic aloe) leaf juice
# aloe barbadensis (organic) leaf extract
# aloe barbadensis flower extract
# aloe barbadensis flower extract (and) lawsonia inermis extract (and) ocimum sanctum leaf (holy basil) extract
# aloe barbadensis leaf extract
# aloe barbadensis leaf extract & saccharomyses cerevisiae (yeast) extract
# aloe barbadensis leaf juice
# aloe barbadensis leaf juice (organic)
# aloe barbadensis leaf juice powder
# aloe barbadensis leaf polysaccharides
# aloe barbadensis leaf water
# aloe barbadensis powder
# aloe barbadensis/aloe barbadensis leaf juice
# aloe barbadensisflower extract
# aloe barbedensis leaf juice
# aloe vera
# aloe vera leaf powder
# aloe yohjyu matsu ekisu
# alpha bisabolol
# alpha isomethyl ionone
# alpha lipoic acid
# alpha-arbutin
# alpha-bisabolol
# alpha-glucan oligosaccharide
# alpha-isomethyl ionone
# alpinia galanga leaf extract
# alpiniagalanga leaf extract
# alteromonas ferment extract
# alteromonas ferment extract (exopolysaccharides)
# alteromonas ferment filtrate
# althaea officinalis (marshmallow) root extract
# althaea officinalis leaf extract
# althaea officinalis root extract
# althaea officinalis root extract+
# althaea officinalis/althaea officinalis root extract
# althaea rosea flower extract
# alumina
# aluminium hydroxide
# aluminum
# aluminum and alumina
# aluminum chlorohydrate
# aluminum dimyristate
# aluminum distearate
# aluminum glycinate
# aluminum hydroxide
# aluminum hydroxide octyldodecyl oleate
# aluminum powder
# aluminum powder (ci 77000)
# aluminum silicate
# aluminum starch octenylsuccinate
# aluminum starch octenylsuccinate (viscosity-complex carbohydrate from plants)
# aluminum stearate
# amaranthus caudatus seed extract
# amaranthus caudatus seed extract (organic)
# amaranthus caudatus seed oil
# amaranthus squalane oil
# amazonian clay: provides total balancing for better
# amber extract
# amber leaf extract
# amber powder
# ambrettolide
# amines
# amino esters-1
# amino-esters-1
# aminobutyric acid
# aminomethyl porpanol
# aminomethyl propanediol
# aminomethyl propanol
# aminopropyl ascorbyl phosphate
# aminopropyl dimethicone
# ammonium
# ammonium acryloyldimethltaurate/vp copolymer
# ammonium acryloyldimethy-ltaurate/vp copolymer
# ammonium acryloyldimethyltaurate
# ammonium acryloyldimethyltaurate/ vp copolymer
# ammonium acryloyldimethyltaurate/beheneth-25 methacrylate crosspolymer
# ammonium acryloyldimethyltaurate/carboxyethyl acrylate crosspolymer
# ammonium acryloyldimethyltaurate/vp copolymer
# ammonium glycyrrhizate
# ammonium hydroxide
# ammonium polyacrylate
# ammonium polyacryldimethyltauramide
# ammonium polyacryldimethyltauramide/ammonium polyacryloyldimethyl taurate
# ammonium polyacryloyl-dimethyl taurate
# ammonium polyacryloyldimethyl taurate
# amodimethicone
# amorphophallus konjac root powder
# amyl cinnamal
# amylopectin
# amyris balsamifera bark oil
# an-themis nobilis flower oil
# anacyclus pyrethrum root extract
# ananas comosus (organic pineapple) fruit extract
# ananas sativas (pineapple) fruit extract
# ananas sativus (organic pineapple) fruit extract
# ananas sativus (pineapple) fruit extract
# ananas sativus fruit extract
# angelica acutiloba root extract
# angelica archangelica root extract
# angelica dahurica root extract
# angelica gigas root extract
# angelica keiskei extract
# angelica keiskei leaf/stem extract
# anhydroxylitol
# aniba rosaeodora (rosewood) wood extract
# aniba rosaeodora (rosewood) wood oil
# aniba rosodora (rosewood) wood oil
# anibarosodora (rosewood)wood oil
# anigozanthos manglesii flower extract
# animal ingredients
# animal ingredients and parabens. in addition
# annatto
# annatto (ci 75120)
# annuus (sunflower) seed oil
# anogeissus leiocarpus bark extract
# anona squamosa seed extract
# anthe mis nobilis flower oil
# anthemis nobilis (chamomile roman) flower oil
# anthemis nobilis (chamomile)
# anthemis nobilis (chamomile) flower extract
# anthemis nobilis (chamomile) flower oil
# anthemis nobilis (chamomile) oil
# anthemis nobilis (english chamomile) oil
# anthemis nobilis (roman chamomile) oil
# anthemis nobilis flower extract
# anthemis nobilis flower oil
# anthemis nobilis flower water
# anthemis nobilisflower oil
# anthemis obilis flower oil
# anthemisnobilis flower oil
# antioxidants
# aphanizomenon flos-aquae extract
# aphanothece sacrum polysaccharide
# apium graveolens (celery) extract
# apple fruit extract
# apricot kernel amino acid
# apricot kernel oil
# apricot seed powder
# aqua
# aqua (water)
# aqua in pool
# aqua/water
# aqua/water/eau
# ar-temisia absinthium extract
# arabidopsis thaliana extract
# arachidic acid
# arachidyl alcohol
# arachidyl glucoside
# arbutin
# arctium lappa (burdock) root extract (8.75%)
# arctium lappa extract/arctium lappa root extract
# arctium lappa root extract
# arctium lappa root extract+
# arctium majus root extract
# arctostaphylos uva ursi (bearberry) leaf extract
# arctostaphylos uva ursi leaf extract
# argan oil
# argan oil isostearyl esters
# argan oil isostearyl esters**. **natural
# argania spinosa (argan) kernel oil
# argania spinosa (argan) oil*. *organic
# argania spinosa kernel extract
# argania spinosa kernel oil
# argania spinosa(argan) kernel oil
# argilla/magnesium aluminum silicate
# arginine
# arginine cocoate
# arginine ethylhexylglycerin
# arginine ferulate
# arginine hci
# arginine hcl
# arginine pca
# arginine/lysine polypeptide
# aristotelia chilensis (maqui berry) fruit juice
# aristotelia chilensis (maqui) fruit extract
# aristotelia chilensis fruit extract
# arnica chamissonis flower extract
# arnica montana (arnica) extract
# arnica montana (flower) extract
# arnica montana (wolf's bane) flower extract
# arnica montana flower extract
# arnica montana flower extract (organic)
# arnica oil
# arnicamonta-na flower extract
# aroma
# aroma/flavor
# aromatherapeutic benefits
# aronia arbutifolia (chokeberry) fruit extract
# aronia melanocarpa fruit extract
# artemia extract
# artemisia absinthium extract
# artemisia princeps leaf extract
# artemisia princeps leaf powder
# artemisia vulgaris extract
# artichoke leaf
# ascophyllum nodosum extract
# ascophyllum nodosum powder
# ascorbic acid
# ascorbic acid (vitamin c)
# ascorbic acid polypeptide
# ascorbyl glucoside
# ascorbyl methylsilanol pectinate
# ascorbyl palmitate
# ascorbyl palmitate (vitamin c)
# ascorbyl tetraisopalmitate
# ascorbyl tocopheryl maleate
# asiatic acid
# asiaticacid
# asiaticoside
# aspalathus linearis (red tea) leaf extract
# aspalathus linearis (rooibos) extract
# aspalathus linearis leaf (red tea) extract
# aspalathus linearis leaf (rooibos/red tea) extract
# aspalathus linearis leaf extract
# asparagopsis armata extract
# asparagus cochinchinensis root extract
# asparagus officinalis stem extract
# aspartic acid
# aspergillus ferment
# aspergillus/camellia sinensis leaf extract ferment filtrate
# aspergillus/rice ferment extract
# aspergillus/saccharomyces/rice ferment filtrate
# astaxanthin
# astragalus membranaceous root extract
# astragalus membranaceus root extract
# astrocaryum murumuru butter
# astrocaryum murumuru seed butter
# atelocollagen
# atractyloides japonica rhizome extract
# atractyloides lancea root extract
# atractyloides macrocephala root extract
# aurantium bergamia (bergamot) fruit oil
# aveena sativa (oat) kernel meal
# avena sativa (oat) bran extract
# avena sativa (oat) kernel extract
# avena sativa (oat) kernel extract+
# avena sativa (oat) kernel flour
# avena sativa (oat) kernel meal
# avena sativa (oat) kernel oil
# avena sativa (oat) kernel protein
# avena sativa flour
# avena sativa flour/oat kernel flour
# avena sativa kernel extract
# avena sativa kernel flour (oat) kernel flour
# avena sative (oat) kernel extract
# avena strigosa seed extract
# averrhoa carambola fruit extract
# averrhoa carambola leaf extract
# avobenzone
# avobenzone (3%)
# avobenzone 2.00%
# avobenzone 2.00%ingredients: water
# avobenzone 3%
# avobenzone 3.0%
# avobenzone 3.00%
# avobenzone(3%)
# avocado fruit extract
# avocado oil
# azulene
# baccharis genistelloides extract
# bacillus ferment
# bacillus/cordyceps sinensis/ganoderma lucidum/inonotus obliquus/lentinus edodes/phellinus linteus/schizophyllum commune/tricholoma matsutake extract ferment filtrate
# bacillus/folic acid ferment extract
# bacillus/soybean ferment extract
# bacillus/soybean/ folic acid ferment extract
# bacillus/soybean/folic acid ferment
# backhousia citriodora oil
# bakuchiol
# balanites aegyptiaca fruit extract
# bam-busa arundinacea stem extract
# bambusa arundinacea (bamboo) stem extract
# bambusa arundinacea stem powder
# bambusa vulgaris (bamboo) extract
# bambusa vulgaris (bamboo) leaf/stem extract
# bambusa vulgaris extract
# bambusa vulgaris leaf/stem extract
# bambusoides juice
# banksia serrata flower extract
# baptisia tinctoria root extract
# baptisia tinctoria root extract+
# barbassu oil
# barium sulfate
# barosma betulina leaf extract
# base concentrate. base: water
# basil oil
# batyl alcohol
# beeswax
# beeswax (cera alba)
# beeswax (organic)
# beeswax/cera alba/cire d'abeille
# beeswax/cire d'abeille
# beet root powder
# beheneth-20
# beheneth-25
# behenic acid
# behentrimonium chloride
# behenyl alcohol
# behenyl alcohol tocopheryl acetate
# behenyl dimer dilinoleate
# behenyl olivate
# behenylalcohol
# belamcanda chinensis root extract
# bellis perennis (daisy) flower extract
# belumbium speciosum flower extract
# benenyl alcohol
# benincasa cerifera seed extract
# bentonite
# benzalkonium chloride
# benzoic acid
# benzophenone-2
# benzophenone-3
# benzophenone-3 (oxybenzone)
# benzophenone-4
# benzophenone-5
# benzyl alcohol
# benzyl alcohol. *certified organic
# benzyl alcohol. step 2: magnesium carbonate
# benzyl benzoate
# benzyl glycol
# benzyl salicylate
# benzylidene dimethoxydimethylindanone
# berberis vulgaris root extract
# beste™ no.9 jelly cleanser: water
# beta carotene
# beta carotene (ci 40800)
# beta glucan
# beta vulgaris (beet) root extract
# beta vulgaris (beet) root extract (extrait de racine de betterave)
# beta vulgaris/ beet root extract/ extrait de racine de betterave
# beta vulgaris/beet root extract/extrait de racine de betterave
# beta-carotene
# beta-carotene (ci 40800)
# beta-carotene (ci 75130)
# beta-caryophyllene
# beta-glucan
# beta-sitosterol
# betaglucan
# betain
# betaine
# betaine salicylate
# betaine tocopheryl acetate ascorbic acid
# betalne
# betula alba (birch) bark extract
# betula alba (birch) extract
# betula alba bark extract
# betula alba extract
# betula alba juice
# betula alba leaf extract
# betula pendula wood powder
# betula platyphylla japonica juice
# bh
# bha
# bht
# bi-facil: water
# bidens pilosa extract
# bifida ferment lysate
# binchotan charcoal paste
# bioflavonoids
# biosaccharide gum - 1
# biosaccharide gum-1
# biosaccharide gum-2
# biosaccharide gum-4
# biotin
# bis(glycidoxyphenyl)propane/bisaminomethylnorbornane copolymer
# bis-behenyl/isostearyl/phytosteryl dimer dilinoleyl dimer dilinoleate
# bis-butyldimethicone polyglyceryl-3
# bis-diglyceryl polyacyladipate-2
# bis-digylceryl polyacyladipate-2
# bis-ethylhexyl hydroxydimethoxy benzylmalonate
# bis-ethylhexyloxyphenol methoxyphenyl triazine
# bis-hydroxyethoxypropyl dimethicone
# bis-peg-12 dimethicone
# bis-peg-15 methyl ether dimethicone
# bis-peg-18 methyl ether dimethyl silane
# bis-peg-18 methyl etherdimethyl silane
# bis-peg/ppg-14/14 dimethicone
# bis-peg/ppg-16/16 peg/ppg-16/16 dimethicone
# bis-peg/ppg-20/5 peg/ppg-20/5 dimethicone
# bis-stearyl dimethicone
# bis-vinyl dimethicone/dimethicone copolymer
# bisabolol
# bismuth oxychloride
# bismuth oxychloride (ci 77163)
# bismuth oxychloride (ci 77163). renewed hope in a jar eye refreshing & refining eye cream: water
# bitter orange flower extract
# bixa orellana seed extract
# bixa orellana seed oil
# black 2 (ci 77266)
# bletia hycinthina bulb extract
# blue 1
# blue 1 (ci 42090)
# blue 1 (ci42090)
# blue 1 lake (ci 42090)
# blue 1 lake)
# blue 1/ci 42090
# blue 4
# blue no. 1 (ci 42090)
# boerhavia diffusa root extract
# borago officinalis (borage) leaf extract
# borago officinalis (borage) oil
# borago officinalis (borage) seed oil
# borago officinalis seed extract
# borago officinalis seed oil
# boron nitride
# boswellia carterii (olibanum) oil
# boswellia carterii oil
# boswellia serrata extract
# brassica campestris (rapeseed) seed oil
# brassica campestris (rapeseed) sterols
# brassica campestris (rapeseed) sterols/brassica campestris sterols
# brassica napus extract
# brassica oleracea (kale) leaf extract
# brassica oleracea acephala leaf extract
# brassica oleracea capitata (cabbage) leaf extract
# brassica oleracea italic (cold pressed broccoli) seed oil
# brassica oleracea italica (broccoli) extract
# brassica oleracea italica (broccoli) sprout extract
# brassica oleracea(kale) leaf extract
# brassica rapa (turnip) leaf extract
# brazil nut oil
# brazilian micronized tourmaline gemstone powder
# brighter look. -evening primrose oil: boosts radiance
# bromates
# bromelain
# broussonetia kazinoki bark extract
# buckwheat seed extract
# buddleja davidii extract
# buddleja davidii meristem cell culture
# buddleja officinalis flower extract
# bukachiol
# bulnesia sarmientoi wood oil
# bupleurum falcatum root extract
# burdock (arctium lapp) 4:1 root extract
# buriti oil
# buteth-3
# butter extract
# butyl acetate
# butyl avocadate
# butyl methoxydibenzoylimethane
# butyl methoxydibenzoylmethane
# butylene glycol
# butylene glycol cocoate
# butylene glycol dicaprylate/dicaprate
# butylene glycol pentylene glycol
# butylene/ethylene/styrene copolymer
# butyleneglycol
# butyloctyl
# butyloctyl salicylate
# butylparaben
# butylphenyl
# butylphenyl met hylpropional
# butylphenyl methylpropional
# butylphenyl methylpropional. *plant origin
# butyro - spermum parkii (shea) butter
# butyrospermum parkii (organic shea butter)
# butyrospermum parkii (shea butter)
# butyrospermum parkii (shea butter) butter
# butyrospermum parkii (shea butter) extract
# butyrospermum parkii (shea butter) fruit
# butyrospermum parkii (shea) bu-tter
# butyrospermum parkii (shea) butter
# butyrospermum parkii (shea) butter extract
# butyrospermum parkii (shea) butter polyglyceryl-3 beeswax
# butyrospermum parkii (shea) nut butter
# butyrospermum parkii (shea)butter
# butyrospermum parkii butter
# butyrospermum parkii butter (butyrospermum parkii (shea butter))
# butyrospermum parkii butter extract (butyrospermum parkii (shea butter) extract)
# butyrospermum parkii butter/shea butter
# butyrospermum parkii nut shell powder
# butyrospermum parkii oil/shea oil
# butyrospermum parkii/shea butter
# butyrospermun parkii (shea butter)
# c10-18 triglycerides
# c10-30 alkyl acrylate crosspolymer
# c10-30 cholesterol
# c12-13 pareth-23
# c12-13 pareth-3
# c12-14 pareth-12
# c12-15 alkyl benzoate
# c12-15 alkyl ethylhexanoate
# c12-15 alkyl lactate
# c12-16 alcohols
# c12-20 acid peg-8 ester
# c12-20 alkyl glucoside
# c12-20 alkyl gucoside
# c13-14 isoparaffin
# c13-14isoparaffin
# c13-15 alkane
# c14-22 alcohols
# c15-23 alkane
# c20-40 pareth-3
# c30 hydrocarbons
# c30-38 olefin/isopropyl maleate/ma copolymer
# c30-45 alkyl cetearyl dimethicone crosspolymer
# c50-45 alkyl cetearyl dimethicone crosspolymer
# c9-12 alkane
# c9-12 alkane (coconut)
# ca-mellia sinensis leaf extract
# caccinium myrtillus (bilberry) fruit extract
# caesalpinia spinosa fruit extract
# caesalpinia spinosa gum
# caffeine
# calcium
# calcium alginate
# calcium aluminum borosilicate
# calcium ascorbate
# calcium carbonate
# calcium chloride
# calcium clubonate
# calcium gluconate
# calcium hydroxymethionine
# calcium ketogluconate
# calcium lactate
# calcium pantothenate
# calcium pca
# calcium sodium borosilicate
# calcium sodium phosphosilicate
# calcium stearate
# calcium sulfate
# calcium sulfate hydrate
# calcium sulfate. step 02 brightening liquid ampoule: water
# calcium sulfate. step 02 firming liquid ampoule: water
# calcium sulfate. step 02 hydro liquid ampoule: water
# calcium sulfate. step 02 soothing liquid ampoule: water
# calcium sulphate
# calcium threonate
# calciumgluconate
# calendula officinalis (calendula) flower extract
# calendula officinalis (pot marigold) flower extract
# calendula officinalis extract
# calendula officinalis extract/calendula officinalis flower extract
# calendula officinalis flower
# calendula officinalis flower extract
# calendula officinalis flower extract*+
# calendula officinalis flower extract+
# calendula oil
# callicarpa japonica fruit extract
# callitris intratropica (blue cypress) oil
# calluna vulgaris extract
# calophyllum inophyllum seed oil
# calophyllum tacamahaca seed oil
# camelia sinensis leaf extract
# camelina sativa seed oil
# camellia
# camellia japonica flower extract
# camellia japonica seed oil
# camellia oleifera (camellia) seed oil
# camellia oleifera (green tea) leaf extract
# camellia oleifera leaf extract
# camellia oleifera leaf juice
# camellia oleifera seed oil
# camellia sinensis
# camellia sinensis (green tea) extract
# camellia sinensis (green tea) leaf
# camellia sinensis (green tea) leaf extract
# camellia sinensis (green tea) leaf powder
# camellia sinensis (green tea) polyphenols
# camellia sinensis (green tea)leaf extract
# camellia sinensis (japanese white tea) leaf extract
# camellia sinensis (white peony tea) leaf
# camellia sinensis (white tea) extract
# camellia sinensis (white tea) leaf extract
# camellia sinensis (yellow tea) leaf extract
# camellia sinensis callus culture conditioned media
# camellia sinensis callus culture extract
# camellia sinensis flower extract
# camellia sinensis leaf
# camellia sinensis leaf (green tea) extract
# camellia sinensis leaf (oolong tea)
# camellia sinensis leaf extract
# camellia sinensis leaf powder
# camellia sinensis leaf water
# camellia sinensis leafextract (organic)
# camellia sinensis seed oil
# camillia sinensis leaf extract
# camphor
# canadian colloidal clay
# cananga
# cananga odorata (ylang ylang) oil
# cananga odorata flower (ylang ylang) oil
# cananga odorata flower extract
# cananga odorata flower oil
# canarium luzonicum (elemi) leaf extract
# candelilla cera
# candelilla cera/euphorbia cerifera (candelilla) wax/cire de candelilla
# candelilla/jojoba/rice bran polyglyceryl-3 esters
# candida bombicola/glucose/methyl rapeseedate ferment
# candleilla wax
# caning odonata flower oil
# cannabis sativa seed oil
# canola oil
# canola oil sunflower seed oil unsaponifiables
# cantella asiatica leaf water
# caprate
# capric acid
# capric triglycerides (fractionated coconut oil)
# capric/ caprylic triglyceride
# caprooyl phytosphingosine
# caprooyl sphingosine
# caprooyl tetrapeptide-3
# capryl/capramidopropyl betaine
# caprylhydroxamic acid
# caprylhydroxamic acid (chelating - amino acid coconut oil)
# caprylhydroxamic acid (chelating - amino acid from coconut oil)
# caprylic /capric triglyceride
# caprylic capric triglyceride
# caprylic/ capric triglyceride
# caprylic/ capric triglyceride teprenone
# caprylic/ca-prictriglyceride
# caprylic/capric glycerides
# caprylic/capric glycerides polyglycerin-10 esters
# caprylic/capric triglycer-acid
# caprylic/capric triglyceride
# caprylic/capric triglyceride (emollient - coconut oil)
# caprylic/capric triglyceride (emollient-coconut oil)
# caprylic/capric triglyceride dicaprylyl carbonate squalane rosa canina fruit oil oenothera biennis oil
# caprylic/capric triglycerides
# caprylic/capric/ myristic/stearic triglyceride
# caprylic/capric/myristic/stearic triglyceride
# caprylic/capric/succinic triglyceride
# caprylic/caprictriglyceride
# caprylic/caprlc triglyceride
# caprylohydroxamic acid
# caprylohydroxamic acid oryza sativa (rice) bran oil
# capryloyl glycerin/sebacic acid copolymer
# capryloyl glycine
# capryloyl pentapeptide-26
# capryloyl salicyclic acid
# capryloyl salicylic acid
# caprylyl
# caprylyl caprylate/caprate
# caprylyl glyceryl ether
# caprylyl glycol
# caprylyl glycol plankton extract
# caprylyl methicone
# caprylyl trimethicone
# caprylyl/capryl glucoside
# caramel
# caramel color
# carbomer
# carbomer sodium polyacrylate
# carbon
# carbon dioxide
# carboxydecyl trisiloxane
# cardiospermum halicacabum flower/leaf/vine extract
# carica papaya (organic papaya) fruit extract
# carica papaya (organic papaya) leaf extract
# carica papaya (papaya) fruit
# carica papaya (papaya) fruit extract
# carica papaya (papaya) fruit water
# carica papaya fruit extract
# carica papaya fruit extract (carica papaya (papaya) fruit extract)
# carica papaya leaf extract
# carica papaya(papaya) fruit water
# carica papya (papaya) fruit extract
# carmine
# carmine (ci 75470)
# carnauba wax
# carnitine
# carnitine hcl
# carnosine
# carob gum
# carrageenan
# carrageenan (red algae origin)
# carrageenan extract
# carthamus tinctorius (organic safflower) oleosomes
# carthamus tinctorius (organic safflower) seed oil
# carthamus tinctorius (safflower) flower extract
# carthamus tinctorius (safflower) oleosomes
# carthamus tinctorius (safflower) seed oil
# carthamus tinctorius (safflower) seed oil avena sativa (oat) peptide
# carthamus tinctorius seed oil
# carthamus tinctorius(safflower) oleosomes
# carya ovata bark extract
# carylic/capric triglyceride
# caryodendron orinocense seed oil
# cassia alata leaf extract
# cassia angustifolia seed polysaccharide
# castanea sativa (chestnut) bark
# castanea sativa (chestnut) seed extract
# castor oil
# caulerpa lentillifera (seaweed) extract
# caulerpa lentillifera extract
# caviar extract
# cedrus atlantica (cedar) wood oil
# cedrus atlantica bark (cedarwood) essential oil
# cedrus atlantica bark oil
# cedrus atlantica wood oil
# cellulose
# cellulose acetate butyrate
# cellulose gum
# cellulose powder
# centaurea cyanus flower extract
# centaurea cyanus flower water
# centaurium erythraea (centaury) extract
# centella asiatica (gotu kola) extract
# centella asiatica (hydrocotyl) extract
# centella asiatica extract
# centella asiatica leaf cell extract
# centella asiatica leaf extract
# centella asiatica leaf water
# centella asiatica meristem cell culture
# centella asiaticameristem cell culture
# centella extract
# centellaasiatica extract
# centellaasiaticaleafwater
# centipeda cunninghamii extract (old man’s weed)
# centrimonium chloride
# cer-amidenp
# cera alba
# cera alba (beeswax)
# cera alba (beeswax)/cire d'abeille
# cera alba/beeswax
# cera alba/beeswax/cire d'abeille
# cera carnauba
# cera carnauba/copernicia cerifera (carnauba) wax/cire de carnauba
# cera microcristallina
# ceramide 1
# ceramide 2
# ceramide 3
# ceramide 3. may contain
# ceramide 6 ii
# ceramide ap
# ceramide as
# ceramide eop
# ceramide eos
# ceramide ng
# ceramide np
# ceramide np (ceramide 3)
# ceramide np (natural lipid - fatty acid rapeseed)
# ceramide np(ceramide 3)
# ceramide ns
# ceramide-3
# ceratonia siliqua (carob) fruit extract
# ceratonia siliqua (carob) gum
# ceratonia siliqua gum
# ceratoniasiliqua gum
# ceresin
# cereus grandiflorus (cactus) flower extract
# certified organic
# certified organic cultivation
# ceteareth-12
# ceteareth-20
# ceteareth-25
# ceteareth-6 olivate
# cetearly alcohol
# cetearyl
# cetearyl alco-hol
# cetearyl alcohol
# cetearyl alcohol (emollient - non-drying fatty alcohol from palm)
# cetearyl alcohol (source coconut oil)
# cetearyl alcohol and ceteareth20
# cetearyl dimethicone
# cetearyl ethylhexanoate
# cetearyl glucoside
# cetearyl glucoside ( source corn)
# cetearyl glucoside (emulsifier/surfactant - coconut)
# cetearyl isononanoate
# cetearyl methicone
# cetearyl olivate
# cetearyl olivate (derived from olive)
# cetearyl olivate (emulsifier - fatty acids from olive oil)
# cetearyl phosphate
# cetearyl wheat straw glycosides
# cetearylisononanoate
# ceteayl olivate
# ceteth-2
# ceteth-20
# ceteth-24
# ceteth-25
# cetheth-20 phosphate
# cetraria islandica extract
# cetrimonium chloride
# cetyl
# cetyl alcohol
# cetyl alcohol (emollient - non-drying fatty alcohol from coconut oil)
# cetyl alcohol polymethylsilsesquioxane
# cetyl behenate
# cetyl diglyceryl tris(trimethylsiloxy)silylethyl dimethicone
# cetyl dimethicone
# cetyl esters
# cetyl ethylhexanoate
# cetyl hydroxyethylcellulose
# cetyl lactate
# cetyl octanoate
# cetyl palmitate
# cetyl peg/ppg 10/1 dimethicone
# cetyl peg/ppg-10/1 dimethi-cone
# cetyl peg/ppg-10/1 dimethicone
# cetyl phosphate
# cetyl ricinoleate
# cetyl stearate
# cetyl triethylmonium dimethicone peg-8 succinate
# cetylhydroxyproline palmitamide
# chaenomeles sinensis fruit extract
# chamaecyparis obtusa leaf extract
# chamaecyparis obtusa water
# chamo milla recutita flower extract
# chamomile
# chamomile flower water
# chamomile recutita (matricaria) flower extract
# chamomile recutita (matricaria) flower oil
# chamomilla recutita (chamomile) flower extract
# chamomilla recutita (matricaria)
# chamomilla recutita (matricaria) extract
# chamomilla recutita (matricaria) flower extract
# chamomilla recutita (matricaria) flower oil
# chamomilla recutita (matricaria) flower water
# chamomilla recutita (matricaria) flower/leaf extract
# chamomilla recutita (matricia) flower (0.5%)
# chamomilla recutita (matricia) flower extract (10.7%)
# chamomilla recutita [chamomilla recutita (matricaria) flower extract
# chamomilla recutita flower extract
# chamomilla recutita flower oil
# chamomilla recutita flower/leaf (organic chamomile) extract
# charcoal -snow lotus
# charcoal extract
# charcoal pore pudding black: water
# charcoal powder
# charcoal: detoxifies. -volcanic pumice: exfoliates. -witch hazel: tones. supermud® clearing treatment: water
# chelidonium majus extract
# cheno - podium quinoa seed extract
# chenopodium quinoa seed extract
# chitosan
# chitosan ascorbate
# chitosan pca
# chlorella ferment
# chlorella minutissima extract
# chlorella protothecoides
# chlorella protothecoides oil
# chlorella pyrenoidosa
# chlorella vulgaris extract
# chlorella vulgaris/lupinus albus proteine ferment
# chlorhexidine digluconate
# chlorhexidine digluconate. may contain: iron oxides
# chlorogenic acids
# chlorophenesin
# chlorophyll
# chlorophyllin-copper
# chlorophyllin-copper complex
# chlorophyllin-copper complex (ci 75810)
# chloroxylenol
# chlorphenesin
# chlorphesin
# cholesterol
# cholesterol/potassium sulfate
# cholesteryl chloride
# cholesteryl dichlorobenzoate
# cholesteryl hydroxystearate
# cholesteryl isostearate
# cholesteryl nonanoate
# cholesteryl oleyl carbonate
# choleth-24
# chondrus crispus
# chondrus crispus (carrageenan)
# chondrus crispus (carrageenan) extract
# chondrus crispus (red algae) extract
# chondrus crispus extract
# chondrus crispus powder
# chondrus crispus powder (carrageenan)
# chondrus crisrus (red algae) extract
# chonrus crispus (carrageenan) extract
# chromium
# chromium hydroxide green
# chromium hydroxide green (ci 77289)
# chromium hydroxide green (ci 77289). sake bright white mask: water
# chromium oxide green
# chromium oxide greens
# chromium oxide greens (ci 77288)
# chromium oxide greens (ci 77288) * essential oil
# chromium picolinate
# chromium polynicotinate
# chrondrus crispus extract
# chrysanthellum indicum extract
# chrysanthemum indicum flower extract
# chrysanthemum parthenium (feverfew) extract
# chrysanthemum parthenium extract
# chrysanthemum sibiricum extract
# chrysin
# ci 14700
# ci 14700 (red 4)
# ci 14700/ red 4
# ci 14700/red 4
# ci 15985 (yellow 6)
# ci 15985/yellow 6
# ci 16035
# ci 17200
# ci 17200 (red 33)
# ci 17200/red 33
# ci 19140
# ci 19140 (yellow 5)
# ci 19140/yellow 5
# ci 19140/yellow5
# ci 42090
# ci 42090 (blue 1)
# ci 42090/blue 1
# ci 60725 (violet 2)
# ci 60730
# ci 60730 (ext. violet 2)
# ci 61565 (green 6)
# ci 75120 (annatto)
# ci 75130 (beta-carotene). *pitera™
# ci 77007 (ultramarines)
# ci 77019 (mica)
# ci 77120 (barium sulfate)
# ci 77163/bismuth oxychloride
# ci 77288
# ci 77288/chromium oxide greens
# ci 77491
# ci 77491 (iron oxides)
# ci 77491 ci 77492 ci 77499 (iron oxides)
# ci 77491)
# ci 77491/77492/77499 (iron oxides)
# ci 77491/iron oxide
# ci 77491/iron oxides
# ci 77492
# ci 77492 (iron oxides)
# ci 77492)
# ci 77492. *pitera
# ci 77492. *pitera™
# ci 77492/iron oxides
# ci 77499
# ci 77499 (iron oxides)
# ci 77499)
# ci 77499). *essential oil
# ci 77499). ginzing™ peel-off mask to refine & refresh: water
# ci 77499/iron oxides
# ci 77891
# ci 77891 (titanium dioxide)
# ci 77891/ titanium dioxide
# ci 77891/titanium dioxide
# ci 77947 (zinc oxide)
# ci77499)
# ci7789/titanium dioxide
# ci77891 (titanium dioxide)
# ci77891/titanium dioxide
# cibic acid
# cicer arietinum seed powder
# cichorium intybus (chicory) root extract
# cimicifuga racemosa root extract
# cinchona succirubra bark extract
# cinnamal
# cinnamic acid
# cinnamomum camphora (camphor) bark oil
# cinnamomum camphora (camphor) leaf extract
# cinnamomum cassia bark extract
# cinnamomum cassia leaf oil
# cinnamomum zeylanicum bark extract
# cinnamyl alcohol
# cire dabeille
# cire de candelilla
# cire de carnauba
# cire microcristalline
# cistus incanus flower/leaf/stem extract
# cistus ladaniferus leaf/stem extract
# cistus monspeliensis extract
# citral
# citrannellol
# citrate
# citric acid
# citric acid* (193/031) *. plant origin
# citric acid* (194/002 ) *. plant origin
# citronella oil
# citronellal
# citronellol
# citronellol. *plant origin
# citronnellol
# citrulline
# citrullus lanatus (watermelon) extract
# citrullus lanatus (watermelon) fruit
# citrullus lanatus (watermelon) fruit extract
# citrullus lanatus (watermelon) seed oil
# citrullus vulgaris (watermelon)
# citrullus vulgaris (watermelon) fruit extract
# citrullus vulgaris (watermelon) fruitextract
# citrullus vulgaris fruit extract (citrullus vulgaris (watermelon) fruit extract)
# citrus
# citrus au-rantium dulcis (orange) fruit extract
# citrus aurantifolia (lime) extract
# citrus aurantifolia (lime) fruit extract
# citrus aurantifolia (lime) oil
# citrus aurantifolia (lime) oil++
# citrus aurantifolia (lime) peel extract
# citrus aurantium (bergamia) peel oil
# citrus aurantium (neroli) oil
# citrus aurantium (orange) fruit extract
# citrus aurantium amara (bitter orange) flower extract
# citrus aurantium amara (bitter orange) flower oil
# citrus aurantium amara (bitter orange) flower water
# citrus aurantium amara (bitter orange) flower wax
# citrus aurantium amara (bitter orange) leaf/twig extract dicaprylyl carbonate
# citrus aurantium amara (bitter orange) leaf/twig oil
# citrus aurantium amara (bitter orange) peel extract
# citrus aurantium amara (bitter orange) peel oil
# citrus aurantium amara (neroli) flower oil
# citrus aurantium amara (neroli) oil
# citrus aurantium amara peel oil
# citrus aurantium bergamia
# citrus aurantium bergamia (bergamot) fruit extract
# citrus aurantium bergamia (bergamot) fruit oil
# citrus aurantium bergamia (bergamot) fruit water
# citrus aurantium bergamia (bergamot) leaf extract
# citrus aurantium dulcis (blood orange) oil
# citrus aurantium dulcis (orange) flower extract
# citrus aurantium dulcis (orange) flower oil
# citrus aurantium dulcis (orange) fruit extract
# citrus aurantium dulcis (orange) fruit water
# citrus aurantium dulcis (orange) oil
# citrus aurantium dulcis (orange) oil** lavandula angustifolia (lavender) oil
# citrus aurantium dulcis (orange) peel extract
# citrus aurantium dulcis (orange) peel oil
# citrus aurantium dulcis (orange) peel oil+
# citrus aurantium dulcis (orange) peel oil++
# citrus aurantium dulcis (orange) peel powder
# citrus aurantium dulcis (orange) peel wax
# citrus aurantium dulcis (organic orange) fruit water
# citrus aurantium dulcis (sweet orange) oil
# citrus aurantium dulcis(orange) flower extract
# citrus aurantium dulcis(orange) fruit extract
# citrus aurantium dulcis(orange) oil
# citrus aurantium flower oil
# citrus aurantium tachibana peel extract
# citrus aurantium var. amara
# citrus aurantium var. amara (neroli) flower oil
# citrus bergamia (bergamot) essential oil
# citrus clementina fruit extract
# citrus glauca fruit extract
# citrus grandis (grapefruit california)
# citrus grandis (grapefruit) fruit extract
# citrus grandis (grapefruit) peel extract
# citrus grandis (grapefruit) peel oil
# citrus grandis (grapefruit) seed extract
# citrus grandis (pomelo grapefruit) seed oil
# citrus junos fruit (yuzu) extract
# citrus junos fruit extract
# citrus junos seed extract
# citrus limon (lemon) fruit extract
# citrus limon (lemon) peel extract
# citrus limon (lemon) peel oil
# citrus limon (lomon) fruit oil
# citrus limon peel extract
# citrus limon peel oil
# citrus medica limonum (lemon) fruit extract
# citrus medica limonum (lemon) peel oil
# citrus medica limonum(lemon) fruit extract
# citrus nobilis (mandarin orange) peel oil
# citrus nobilis fruit extract
# citrus paradisi (grapefruit)
# citrus paradisi (grapefruit) fruit extract
# citrus paradisi (grapefruit) peel oil
# citrus paradisi (grapefruit) seed extract
# citrus paradisii (grapefruit) peel oil
# citrus reticulata (mandarin red) peel oil
# citrus reticulata (tangerine) leaf oil
# citrus reticulata (tangerine) peel extract
# citrus reticulata (tangerine) peel oil
# citrus reticulata peel extract/citrus reticulata (tangerine) peel extract
# citrus sinensis (orange) fruit extract
# citrus sinensis (sweet orange) oil
# citrus sinensis (sweet orange) peel oil
# citrus sinensis peel oil expressed
# citrus tachibana
# citrus tangerina (tangerine) extract
# citrus tangerina (tangerine) peel extract
# citrus tangerina (tangerine) peel oil
# citrus unshiu peel extract
# citrusgrandis (grapefruit) peel oil
# cl 77492 (iron oxides). *pitera™
# cladosiphon okamuranus extract
# clay mineral oxides
# cleanses
# cnidium officinale root extract
# coats
# cocamide mea
# cocamidopro-pyl betaine
# cocamidopropyl betaine
# cocamidopropyl dimethylamine
# cocamidopropyl hydroxysultaine
# cocamidopropyl pg-dimonium chloride phosphate
# coccinia indica fruit extract
# coccinia indica fruit extract (neer sikkappu red)
# coceth-7
# cochlearia armoracia (horseradish) root extract
# coco caprylate
# coco glucoside
# coco glucoside (coconut and sunflower oil)
# coco-betaine
# coco-caprylate
# coco-caprylate/ caprate
# coco-caprylate/caprate
# coco-caprylate/caprate (emollient - coconut oil)
# coco-glucoside
# cocoa seed butter
# cocobetaine
# cocoglycerides
# cocoglycerides rosmarinus officinalis (rosemary) leaf extract
# cocomidopropyl betaine
# coconut acid
# coconut alcohol
# coconut alkanes
# coconut face mask: water
# coconut nucifera (coconut) extract
# coconut oil polyglyceryl-6 esters
# cocos nu-cifera (coconut) fruit extract
# cocos nucifera (coconut) extract
# cocos nucifera (coconut) fruit extract
# cocos nucifera (coconut) fruit juice
# cocos nucifera (coconut) oil
# cocos nucifera (coconut) shell powder
# cocos nucifera (coconut) water
# cocos nucifera (coconut/ noix de coco) oil
# cocos nucifera(coconut) fruit extract
# cocoyl hydroxyethyl imidazoline
# cocoyl proline
# cocyl arginine amide
# codium fragile extract
# codium tomentosum extract
# codonopsis lanceolata root extract(8.75%)
# coenzyme a
# coffea arabica (coffee) extract
# coffea arabica (coffee) seed extract
# coffea robusta seed extract
# coffee arabica seed extract
# coix lacryma-jobi ma yuen seed extract
# coix lacryma-jobi ma-yuen seed extract
# cola acuminata (kola) seed extract
# cola nitida (kola) seed extract
# cold pressed avocado) oil
# cold pressed concord grape) seed oil
# coleus barbatus extract
# coleus barbatus root (forskolin) extract
# coleus barbatus root (viapure coleus) extract
# coleus forskohlii root extract
# collagen
# collagen amino acids
# collodial oatmeal
# colloidal gold
# colloidal oatmeal
# colloidal oatmeal (soothing - oatmeal)
# colloidal platinum
# colloidal platinum [nano
# colloidal silver
# colloidal sulfur
# commiphora mukul resin extract
# commiphora myrrha (myrrh) oil
# commiphora myrrha leaf cell extract
# commiphora myrrha leaf cell extract trisodium ethylenediamine disuccinate
# commiphora myrrha oil
# commiphora myrrha resin extract
# conchiolin powder
# copaifera officinalis (balsam copaiba) resin
# copernicia cerifera (carnauba) wax
# copernicia cerifera (carnauba) wax\cera carnauba\cire de carnauba
# copernicia cerifera cera
# copolymer
# copper
# copper chlorophyll
# copper complex gluconate
# copper gluconate
# copper lysinate/prolinate
# copper lysine prolinate
# copper palmitoyl heptapeptide-14
# copper pca
# copper tripeptide-1
# coptis japonica extract
# coptis japonica root extract
# coq10
# coral powder. step two: water
# corallina officinalis extract
# corchorus olitorius leaf extract
# corcuma longa (turmeric) root extract
# cordyceps sinensis (mushroom) extract
# cordyceps sinensis extract
# coriander seed oil
# coriander seed oil tocopherol lavandula angustifolia oil
# coriandrum sativum (coriander)
# coriandrum sativum (coriander) fruit oil
# coriandrum sativum (coriander) seed extract
# coriandrum sativum (coriander) seed oil
# corn (zea mays) oil
# corn oil
# corn starch
# corn starch modified
# cornus officinalis fruit extract
# corralina officinalis extract
# corylus americana (hazel) seed extract
# corylus avellana (hazel) seed oil
# coumarin
# coumarin.*plant origin
# crambe abyssinica seed oil
# crambe maritima leaf extract
# crataegus monogyna flower extract
# creatine
# creating a natural-looking glow
# crithmum maritimum callus culture filtrate
# crithmum maritimum extract
# crocus sativus stigma extract
# croscarmellose sodium
# crosspolymer
# crosspolymer isohexadecane
# cryptomeria japonica bud extract
# cryptomeria japonica leaf extract
# crysanthemum parthenium (feverfew) extract
# cucumber fruit extract
# cucumber fruit extract curcuma longa extract
# cucumis melo (melon) fruit extract
# cucumis melo cantalupensis fruit extract
# cucumis sativus (cucumber) extract
# cucumis sativus (cucumber) fruit extract
# cucumis sativus (cucumber) oil
# cucumis sativus (cucumber) seed oil
# cucumis sativus (organic cucumber) fruit extract
# cucumis sativus [cucumis sativus (cucumber) fruit extract
# cucumis sativus extract
# cucumis sativus fruit extract
# cucumis sativus fruit extract/cucumber fruit extract
# cucumis sativus(cucumber) fruit extract
# cucumismelo (melon) fruit extract
# cucums sativus (cucumber) extract
# cucurbita pepo (pumpkin)
# cucurbita pepo (pumpkin) fruit extract
# cucurbita pepo (pumpkin) seed oil
# cupressus sempervirens leaf/nut/stem oil
# cupressus sempervirens leaf/stem extract
# cupressus sempervirens oil
# cupressus sempervirens seed extract
# cupuacu butter glycerides
# curcuma lo-nga (turmeric) root extract
# curcuma longa (tumeric) root extract
# curcuma longa (turmeric) root extract
# curcuma longa extract
# curcuma longa extract/turmeric root extract
# curcuma longa rhizome extract
# curcuma longa root extract
# curcuma longa root extract/turmeric root extract
# curcumin
# curuma longa (turmeric) root extract
# cyamopsis tetragonoloba (guar) gum
# cyanocobalamin
# cyathea cumingii leaf extract
# cyathea medullaris leaf extract
# cyclodextrin
# cyclohexasiloxane
# cyclohexasiloxanehydroxyethylacrylate
# cyclomethicone
# cyclopentasiloxane
# cyclopentasiloxane -tromethamine
# cyclopentasilxane
# cyclotetrasiloxane
# cylindrica root extract
# cylindrotheca fusiformis extract
# cymbidium grandiflorum (orchid) flower extract
# cymbopogan schoenanthus (lemongrass) oil
# cymbopogon citratus extract
# cymbopogon citratus leaf oil
# cymbopogon flexuosus (lemon grass) oil
# cymbopogon flexuosus (lemongrass) oil
# cymbopogon martini (palmarosa) oil
# cymbopogon martini oil
# cymbopogon schoenanthus (lemongrass) oil
# cymbopogon schoenanthus essential oil
# cymbopogon schoenanthus extract
# cymbopogon schoenanthus oil
# cynara scolymus (artichoke) leaf extract
# cynara scolymus leaf extract/ cynara scolymus (artichoke) leaf extract
# cynara scrolymus (artichoke) leaf extract
# cyperus esculentus tuber extract
# cypripedium pubescens (lady's slipper orchid) extract
# cysteine
# d&c red no. 33 (ci 17200)
# d-calcium pantothenate
# d-limonene
# d-panthenol
# d.e.a
# dandelion leaf
# dandelion root
# daphne odora callus extract
# darutoside
# darutoside*. *plant origin
# daucus carota sativa (carrot) root extract
# daucus carota sativa (carrot) seed oil
# daucus carota sativa (cold pressed wild carrot) seed oil
# decapeptide-22
# decarboxy carnosine hcl
# declustered water (+)/aqua/eau de-structuree (+)
# declustered water (-)/aqua/eau de-structuree (-)
# decyl cocoate
# decyl glucoside
# decyl glucoside (veg. oils & sugar)
# decyl oleate
# decylene glycol
# decyloxazolidinone
# dehydeoacetic acid
# dehydroacetic acid
# dehydroacetic acid & benzyl alcohol
# dehydroacetic acid. * certified organic
# dehydroacetic acid. pink clay mask: water
# dehydroxanthan gum
# denatonium benzoate
# dextran
# dextrin
# dextrin palmitate
# dextrin palmitate/ethylhexanoate
# di-c12-13 alkyl malate
# di-c12-15 alkyl fumarate
# di-c12-18 alkyl dimonium chloride
# di-methicone
# di-ppg-2 myreth-10 adipate
# di-ppg-3 myristyl ether adipate
# diamond powder
# diatomaceous earth

# %% [markdown]
# ### Canonization rules that collapse many equivalent forms (water/aqua/eau, CI pigments, citrus variants, etc.) into one canonical token.

# %%
CANON_RULES: List[Tuple[str, List[str]]] = [
    #water / base-water 
    ("water", [
        r".*:\s*water\s*$",
        r".*ingredients:\s*water\s*$",
        r".*\bbase:\s*water\s*$",
        r".*\bbase concentrate.*water\s*$",
        r".*\bmask:\s*water\s*$",
        r".*\bcleanser:\s*water\s*$",
        r".*\beye.*cream:\s*water\s*$",

        r"^\s*aqua\s*$",
        r"^\s*water\s*$",
        r"^\s*eau\s*$",
        r"aqua\s*/\s*water\s*/\s*eau",
        r"water\s*/\s*aqua\s*/\s*eau",
        r"aqua\s*\(water\)",
        r"water\s*\(aqua\)",
        r"purified\s+water",
    ]),

    ("fragrance", [
        r"^\s*parfum\s*$",
        r"^\s*fragrance\s*$",
        r"parfum\s*\(fragrance\)",
        r"fragrance\s*\(parfum\)",
        r"fragrance\s*/\s*parfum",
        r"parfum\s*/\s*fragrance",
        r"natural\s+fragrance",
        r"\baroma\b",
        r"\bflavor\b",
    ]),

    ("vitamin e", [
        r"\btocopherol\b",
        r"\btocopheryl\s+acetate\b",
        r"\btocopheryl\s+succinate\b",
        r"\btocotrienols\b",
    ]),

    # pigments 
    ("mica", [r"\bmica\b", r"\bci\s*77019\b"]),

    ("titanium dioxide", [
        r"titanium\s+dioxide",
        r"\bci\s*77891\b",
        r"\bci77891\b",
        r"\bci7789\b",
    ]),

    ("iron oxides", [
        r"iron\s+oxides",
        r"\bci\s*77491\b",
        r"\bci\s*77492\b",
        r"\bci\s*77499\b",
        r"\b77491\b",
        r"\b77492\b",
        r"\b77499\b",
    ]),

    # citrus 
    ("orange extract", [
        r"citrus\s+sinensis",
        r"aurantium\s+dulcis",
        r"\borange\b.*\b(peel|fruit|flower|leaf|oil|water|extract|powder|wax)\b",
        r"\b(sweet|blood)\s+orange\b",
    ]),

    ("lemon extract", [
        r"citrus\s+limon",
        r"medica\s+limonum",
        r"\blemon\b.*\b(peel|fruit|oil|water|extract|powder)\b",
    ]),

    ("lime extract", [
        r"citrus\s+aurantifolia",
        r"\blime\b.*\b(peel|fruit|oil|water|extract|powder)\b",
    ]),

    ("grapefruit extract", [
        r"citrus\s+paradisi",
        r"citrus\s+grandis",
        r"\b(grapefruit|pomelo)\b.*\b(peel|fruit|oil|water|extract|powder)\b",
    ]),

    ("bergamot extract", [
        r"citrus\s+aurantium\s+bergamia",
        r"aurantium\s+bergamia",
        r"\bbergamot\b.*\b(peel|fruit|oil|water|extract|powder)\b",
    ]),

    ("mandarin/tangerine extract", [
        r"citrus\s+reticulata",
        r"citrus\s+nobilis",
        r"citrus\s+tangerina",
        r"\b(mandarin|tangerine)\b.*\b(peel|fruit|oil|water|extract|powder)\b",
    ]),

    ("yuzu extract", [
        r"citrus\s+junos",
        r"\byuzu\b.*\b(peel|fruit|oil|water|extract|powder)\b",
    ]),
]

# %%
CANON_RULES_COMPILED = [
    (canon, [re.compile(pat) for pat in pats])
    for canon, pats in CANON_RULES
]

def apply_canon_to_tokens(
    tokens: list[str],
    canon_rules_compiled: list[tuple[str, list[re.Pattern]]],
) -> list[str]:
    if not isinstance(tokens, list):
        return []

    out = []
    seen = set()

    for tok in tokens:
        t = tok.strip()
        if not t:
            continue

        canon = None
        for canon_token, patterns in canon_rules_compiled:
            if any(p.search(t) for p in patterns):
                canon = canon_token
                break

        final_tok = canon if canon else t

        if final_tok not in seen:
            out.append(final_tok)
            seen.add(final_tok)

    return out

df_step2["ingredient_tokens"] = df_step2["ingredient_tokens"].apply(
    lambda toks: apply_canon_to_tokens(toks, CANON_RULES_COMPILED)
)

df_step2[["Brand", "Name", "ingredient_tokens"]].head(5)
# Out:
#             Brand                                         Name  \
# 0          La Mer                              Crème de la Mer
# 1           Sk-Ii                     Facial Treatment Essence
# 2  Drunk Elephant                    Protini Polypeptide Cream
# 3          La Mer                  The Moisturizing Soft Cream
# 4    It Cosmetics  Your Skin But Better CC+ Cream with SPF 50+
#
#                                    ingredient_tokens
# 0  [algae (seaweed) extract, mineral oil, petrola...
# 1  [galactomyces ferment filtrate (pitera), butyl...
# 2  [water, dicaprylyl carbonate, glycerin, cetear...
# 3  [algae (seaweed) extract, cyclopentasiloxane, ...
# 4  [water, snail secretion filtrate, phenyl trime...

# %%
df_step3 = df_step2.copy()
df_step3[["Brand","Name","Ingredients","ingredient_tokens"]].head(10)
# Out:
#                 Brand                                               Name  \
# 0              La Mer                                    Crème de la Mer
# 1               Sk-Ii                           Facial Treatment Essence
# 2      Drunk Elephant                          Protini Polypeptide Cream
# 3              La Mer                        The Moisturizing Soft Cream
# 4        It Cosmetics        Your Skin But Better CC+ Cream with SPF 50+
# 5              Tatcha                                    The Water Cream
# 6      Drunk Elephant                           Lala Retro Whipped Cream
# 7      Drunk Elephant                    Virgin Marula Luxury Facial Oil
# 8  Kiehl'S Since 1851                                 Ultra Facial Cream
# 9              La Mer  Little Miss Miracle Limited-Edition Crème de l...
#
#                                          Ingredients  \
# 0  algae (seaweed) extract, mineral oil, petrolat...
# 1  galactomyces ferment filtrate (pitera), butyle...
# 2  water, dicaprylyl carbonate, glycerin, ceteary...
# 3  algae (seaweed) extract, cyclopentasiloxane, p...
# 4  water, snail secretion filtrate, phenyl trimet...
# 5  water, saccharomyces/camellia sinensis leaf/cl...
# 6  water, glycerin, caprylic/ capric triglyceride...
# 7  100% unrefined sclerocraya birrea (marula) ker...
# 8  water, glycerin, cyclohexasiloxane, squalane, ...
# 9  algae (seaweed) extract, mineral oil, petrolat...
#
#                                    ingredient_tokens
# 0  [algae (seaweed) extract, mineral oil, petrola...
# 1  [galactomyces ferment filtrate (pitera), butyl...
# 2  [water, dicaprylyl carbonate, glycerin, cetear...
# 3  [algae (seaweed) extract, cyclopentasiloxane, ...
# 4  [water, snail secretion filtrate, phenyl trime...
# 5  [water, saccharomyces/camellia sinensis leaf/c...
# 6  [water, glycerin, caprylic/ capric triglycerid...
# 7  [100% unrefined sclerocraya birrea (marula) ke...
# 8  [water, glycerin, cyclohexasiloxane, squalane,...
# 9  [algae (seaweed) extract, mineral oil, petrola...

# %%
PROCESSED_PATH = Path("datasets") / "cosmetics_processed_clean_tokens.csv"
PROCESSED_PATH.parent.mkdir(parents=True, exist_ok=True)

df_step3.to_csv(PROCESSED_PATH, index=False)
print(f"Processed dataset saved to: {PROCESSED_PATH.resolve()}")
# Out:
# Processed dataset saved to: /Users/sabinabacaoanu/SkinCares/miguellib/datasets/datasets/cosmetics_processed_clean_tokens.csv
